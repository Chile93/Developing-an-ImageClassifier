# %% [markdown]
# # Developing an AI application
#
# Going forward, AI algorithms will be incorporated into more and more everyday applications. For example, you might want to include an image classifier in a smart phone app. To do this, you'd use a deep learning model trained on hundreds of thousands of images as part of the overall application architecture. A large part of software development in the future will be using these types of models as common parts of applications.
#
# In this project, you'll train an image classifier to recognize different species of flowers. You can imagine using something like this in a phone app that tells you the name of the flower your camera is looking at. In practice you'd train this classifier, then export it for use in your application. We'll be using [this dataset](http://www.robots.ox.ac.uk/~vgg/data/flowers/102/index.html) of 102 flower categories, you can see a few examples below.
#
# <img src='assets/Flowers.png' width=500px>
#
# The project is broken down into multiple steps:
#
# * Load and preprocess the image dataset
# * Train the image classifier on your dataset
# * Use the trained classifier to predict image content
#
# We'll lead you through each part which you'll implement in Python.
#
# When you've completed this project, you'll have an application that can be trained on any set of labeled images. Here your network will be learning about flowers and end up as a command line application. But, what you do with your new skills depends on your imagination and effort in building a dataset. For example, imagine an app where you take a picture of a car, it tells you what the make and model is, then looks up information about it. Go build your own dataset and make something new.
#
# First up is importing the packages you'll need. It's good practice to keep all the imports at the beginning of your code. As you work through this notebook and find you need to import a package, make sure to add the import up here.

# %%
# Imports here
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import torch
from torch import nn
from torch import tensor
from torch import optim
import torch.nn.functional as F
from torch.autograd import Variable
from torchvision import datasets, transforms, models
import torchvision.models as models
import argparse
from collections import OrderedDict
import json
import PIL
import seaborn as sns
from PIL import Image
import time
import copy

# %% [markdown]
# ## Load the data
#
# Here you'll use `torchvision` to load the data ([documentation](http://pytorch.org/docs/0.3.0/torchvision/index.html)). The data should be included alongside this notebook, otherwise you can [download it here](https://s3.amazonaws.com/content.udacity-data.com/nd089/flower_data.tar.gz). The dataset is split into three parts, training, validation, and testing. For the training, you'll want to apply transformations such as random scaling, cropping, and flipping. This will help the network generalize leading to better performance. You'll also need to make sure the input data is resized to 224x224 pixels as required by the pre-trained networks.
#
# The validation and testing sets are used to measure the model's performance on data it hasn't seen yet. For this you don't want any scaling or rotation transformations, but you'll need to resize then crop the images to the appropriate size.
#
# The pre-trained networks you'll use were trained on the ImageNet dataset where each color channel was normalized separately. For all three sets you'll need to normalize the means and standard deviations of the images to what the network expects. For the means, it's `[0.485, 0.456, 0.406]` and for the standard deviations `[0.229, 0.224, 0.225]`, calculated from the ImageNet images.  These values will shift each color channel to be centered at 0 and range from -1 to 1.

# %%
data_dir = 'flowers'
train_dir = data_dir + '/train'
valid_dir = data_dir + '/valid'
test_dir = data_dir + '/test'

# %%
# TODO: Define your transforms for the training, validation, and testing sets

#The transform RandomResizedCrop crops the input image by a random size.
#RandomHorizontalFlip randomly flips the image horizontally with a default probability of 50%.
#CenterCrop crops an 224×224 image from the center.
#Normalize takes in a 3 channel Tensor and normalizes each channel by the input mean and standard deviation for the channel.
#and Each channel in the tensor is normalized as T = (T – mean)/(standard deviation)
#All the above transformations are chained together using Compose.

data_transforms = { 
    'train': transforms.Compose([
        transforms.RandomResizedCrop(size=224),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize([0.485,0.456,0.406],
                             [0.229,0.224,0.225])
    ]),
    'valid': transforms.Compose([
        transforms.Resize(size=256),
        transforms.CenterCrop(size=224),
        transforms.ToTensor(),
        transforms.Normalize([0.485,0.456,0.406],
                             [0.229,0.224,0.225])
    ]),
    'test': transforms.Compose([
        transforms.Resize(size=256),
        transforms.CenterCrop(size=224),
        transforms.ToTensor(),
        transforms.Normalize([0.485,0.456,0.406],
                             [0.229,0.224,0.225])
    ])
}

# %%
# TODO: Load the datasets with ImageFolder
image_datasets = {
    'train': datasets.ImageFolder(train_dir, transform=data_transforms['train']),
    'valid': datasets.ImageFolder(valid_dir, transform=data_transforms['valid']),
    'test': datasets.ImageFolder(test_dir, transform=data_transforms['test'])
}

# %%
# TODO: Using the image datasets and the trainforms, define the dataloaders
train_loader = torch.utils.data.DataLoader(image_datasets['train'], batch_size=64, shuffle=True)
validation_loader = torch.utils.data.DataLoader(image_datasets['valid'], batch_size =64,shuffle = True)
test_loader = torch.utils.data.DataLoader(image_datasets['test'], batch_size = 64, shuffle = True)

# Size of Loaders, to be used for calculating Average Loss and Accuracy
train_Loader_size = len(train_loader)
valid_Loader_size = len(validation_loader)
test_loader_size = len(test_loader)

# %%
# Print the train, validation and test set data sizes
train_Loader_size, valid_Loader_size, test_loader_size
# Out:
# (103, 13, 13)

# %% [markdown]
# ### Label mapping
#
# You'll also need to load in a mapping from category label to category name. You can find this in the file `cat_to_name.json`. It's a JSON object which you can read in with the [`json` module](https://docs.python.org/2/library/json.html). This will give you a dictionary mapping the integer encoded categories to the actual names of the flowers.

# %%
import json

with open('cat_to_name.json', 'r') as f:
    cat_to_name = json.load(f)
cat_to_name
# Out:
# {'21': 'fire lily',
#  '3': 'canterbury bells',
#  '45': 'bolero deep blue',
#  '1': 'pink primrose',
#  '34': 'mexican aster',
#  '27': 'prince of wales feathers',
#  '7': 'moon orchid',
#  '16': 'globe-flower',
#  '25': 'grape hyacinth',
#  '26': 'corn poppy',
#  '79': 'toad lily',
#  '39': 'siam tulip',
#  '24': 'red ginger',
#  '67': 'spring crocus',
#  '35': 'alpine sea holly',
#  '32': 'garden phlox',
#  '10': 'globe thistle',
#  '6': 'tiger lily',
#  '93': 'ball moss',
#  '33': 'love in the mist',
#  '9': 'monkshood',
#  '102': 'blackberry lily',
#  '14': 'spear thistle',
#  '19': 'balloon flower',
#  '100': 'blanket flower',
#  '13': 'king protea',
#  '49': 'oxeye daisy',
#  '15': 'yellow iris',
#  '61': 'cautleya spicata',
#  '31': 'carnation',
#  '64': 'silverbush',
#  '68': 'bearded iris',
#  '63': 'black-eyed susan',
#  '69': 'windflower',
#  '62': 'japanese anemone',
#  '20': 'giant white arum lily',
#  '38': 'great masterwort',
#  '4': 'sweet pea',
#  '86': 'tree mallow',
#  '101': 'trumpet creeper',
#  '42': 'daffodil',
#  '22': 'pincushion flower',
#  '2': 'hard-leaved pocket orchid',
#  '54': 'sunflower',
#  '66': 'osteospermum',
#  '70': 'tree poppy',
#  '85': 'desert-rose',
#  '99': 'bromelia',
#  '87': 'magnolia',
#  '5': 'english marigold',
#  '92': 'bee balm',
#  '28': 'stemless gentian',
#  '97': 'mallow',
#  '57': 'gaura',
#  '40': 'lenten rose',
#  '47': 'marigold',
#  '59': 'orange dahlia',
#  '48': 'buttercup',
#  '55': 'pelargonium',
#  '36': 'ruby-lipped cattleya',
#  '91': 'hippeastrum',
#  '29': 'artichoke',
#  '71': 'gazania',
#  '90': 'canna lily',
#  '18': 'peruvian lily',
#  '98': 'mexican petunia',
#  '8': 'bird of paradise',
#  '30': 'sweet william',
#  '17': 'purple coneflower',
#  '52': 'wild pansy',
#  '84': 'columbine',
#  '12': "colt's foot",
#  '11': 'snapdragon',
#  '96': 'camellia',
#  '23': 'fritillary',
#  '50': 'common dandelion',
#  '44': 'poinsettia',
#  '53': 'primula',
#  '72': 'azalea',
#  '65': 'californian poppy',
#  '80': 'anthurium',
#  '76': 'morning glory',
#  '37': 'cape flower',
#  '56': 'bishop of llandaff',
#  '60': 'pink-yellow dahlia',
#  '82': 'clematis',
#  '58': 'geranium',
#  '75': 'thorn apple',
#  '41': 'barbeton daisy',
#  '95': 'bougainvillea',
#  '43': 'sword lily',
#  '83': 'hibiscus',
#  '78': 'lotus lotus',
#  '88': 'cyclamen',
#  '94': 'foxglove',
#  '81': 'frangipani',
#  '74': 'rose',
#  '89': 'watercress',
#  '73': 'water lily',
#  '46': 'wallflower',
#  '77': 'passion flower',
#  '51': 'petunia'}

# %%
# Viewing the fower type dataset
df = pd.DataFrame({'flower_type': cat_to_name})
df[:10]
# Out:
#          flower_type
# 1      pink primrose
# 10     globe thistle
# 100   blanket flower
# 101  trumpet creeper
# 102  blackberry lily
# 11        snapdragon
# 12       colt's foot
# 13       king protea
# 14     spear thistle
# 15       yellow iris

# %% [markdown]
# # Building and training the classifier
#
# Now that the data is ready, it's time to build and train the classifier. As usual, you should use one of the pretrained models from `torchvision.models` to get the image features. Build and train a new feed-forward classifier using those features.
#
# We're going to leave this part up to you. Refer to [the rubric](https://review.udacity.com/#!/rubrics/1663/view) for guidance on successfully completing this section. Things you'll need to do:
#
# * Load a [pre-trained network](http://pytorch.org/docs/master/torchvision/models.html) (If you need a starting point, the VGG networks work great and are straightforward to use)
# * Define a new, untrained feed-forward network as a classifier, using ReLU activations and dropout
# * Train the classifier layers using backpropagation using the pre-trained network to get the features
# * Track the loss and accuracy on the validation set to determine the best hyperparameters
#
# We've left a cell open for you below, but use as many as you need. Our advice is to break the problem up into smaller parts you can run separately. Check that each part is doing what you expect, then move on to the next. You'll likely find that as you work through each part, you'll need to go back and modify your previous code. This is totally normal!
#
# When training make sure you're updating only the weights of the feed-forward network. You should be able to get the validation accuracy above 70% if you build everything right. Make sure to try different hyperparameters (learning rate, units in the classifier, epochs, etc) to find the best model. Save those hyperparameters to use as default values in the next part of the project.
#
# One last important tip if you're using the workspace to run your code: To avoid having your workspace disconnect during the long-running tasks in this notebook, please read in the earlier page in this lesson called Intro to
# GPU Workspaces about Keeping Your Session Active. You'll want to include code from the workspace_utils.py module.
#
# <font color='red'>**Note for Workspace users:** If your network is over 1 GB when saved as a checkpoint, there might be issues with saving backups in your workspace. Typically this happens with wide dense layers after the convolutional layers. If your saved checkpoint is larger than 1 GB (you can open a terminal and check with `ls -lh`), you should reduce the size of your hidden layers and train again.</font>

# %%
# TODO: Build and train your network

# Load pretrained vgg16 Model
model = models.vgg16(pretrained=True)
model
# Out:
# Downloading: "https://download.pytorch.org/models/vgg16-397923af.pth" to /root/.torch/models/vgg16-397923af.pth
# 100%|██████████| 553433881/553433881 [00:05<00:00, 101710333.16it/s]
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU(inplace)
#     (2): Dropout(p=0.5)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU(inplace)
#     (5): Dropout(p=0.5)
#     (6): Linear(in_features=4096, out_features=1000, bias=True)
#   )
# )

# %%
#to freeze part of the convolutional part of vgg16 model and train the rest
for param in model.parameters():
    param.requires_grad = False

# %%
#Used OrderedDict to preserve the order in which the keys are inserted
from collections import OrderedDict

classifier = nn.Sequential(OrderedDict([
            ('inputs', nn.Linear(25088, 120)), #hidden layer 1 sets output to 120
            ('relu1', nn.ReLU()),
            ('dropout',nn.Dropout(0.5)), #could use a different dropout probability, but 0.5 usually works well
            ('hidden_layer1', nn.Linear(120, 90)), #hidden layer 2 output to 90
            ('relu2',nn.ReLU()),
            ('hidden_layer2',nn.Linear(90,70)), #hidden layer 3 output to 70
            ('relu3',nn.ReLU()),
            ('hidden_layer3',nn.Linear(70,102)),#output size = 102
            ('output', nn.LogSoftmax(dim=1))]))# For using NLLLoss()
   
model.classifier = classifier

# %%
# Convert model to be used on GPU
if torch.cuda.is_available():
    model.cuda()
    
criterion = nn.NLLLoss()
optimizer = optim.Adam(model.classifier.parameters(), lr=0.001)

# %%
# Number of steps for gradient descent to take
epochs=19
for epoch in range(epochs):
    print("Epoch: {}/{}".format(epoch+1, epochs))


    # Set to training mode
    model.train()

    # Loss and Accuracy within the epoch
    train_loss = 0.0
    train_acc = 0.0

    valid_loss = 0.0
    valid_acc = 0.0

    for i, (inputs, labels) in enumerate(train_loader):

        inputs = inputs.to('cuda')
        labels = labels.to('cuda')

        # Clean existing gradients
        optimizer.zero_grad()

        # Forward pass - compute outputs on input data using the model
        outputs = model(inputs)

        # Compute loss
        loss = criterion(outputs, labels)

        # Backpropagate the gradients
        loss.backward()

        # Update the parameters
        optimizer.step()

        # Compute the total loss for the batch and add it to train_loss
        train_loss += loss.item() * inputs.size(0)

        # Compute the accuracy
        ret, predictions = torch.max(outputs.data, 1)
        correct_counts = predictions.eq(labels.data.view_as(predictions))

        # Convert correct_counts to float and then compute the mean
        acc = torch.mean(correct_counts.type(torch.FloatTensor))

        # Compute total accuracy in the whole batch and add to train_acc
        train_acc += acc.item() * inputs.size(0)

        print("Batch no: {:03d}, Loss on trainig: {:.4f}, Accuracy: {:.4f}".format(i, loss.item(), acc.item()))
# Out:
# Epoch: 1/19
# Batch no: 000, Loss on trainig: 4.6231, Accuracy: 0.0000
# Batch no: 001, Loss on trainig: 4.6053, Accuracy: 0.0000
# Batch no: 002, Loss on trainig: 4.6381, Accuracy: 0.0000
# Batch no: 003, Loss on trainig: 4.6551, Accuracy: 0.0000
# Batch no: 004, Loss on trainig: 4.8124, Accuracy: 0.0156
# Batch no: 005, Loss on trainig: 4.6915, Accuracy: 0.0156
# Batch no: 006, Loss on trainig: 4.6495, Accuracy: 0.0000
# Batch no: 007, Loss on trainig: 4.5830, Accuracy: 0.0000
# Batch no: 008, Loss on trainig: 4.6686, Accuracy: 0.0156
# Batch no: 009, Loss on trainig: 4.5231, Accuracy: 0.0312
# Batch no: 010, Loss on trainig: 4.5891, Accuracy: 0.0312
# Batch no: 011, Loss on trainig: 4.6015, Accuracy: 0.0156
# Batch no: 012, Loss on trainig: 4.5692, Accuracy: 0.0625
# Batch no: 013, Loss on trainig: 4.5841, Accuracy: 0.0312
# Batch no: 014, Loss on trainig: 4.5229, Accuracy: 0.0625
# Batch no: 015, Loss on trainig: 4.5989, Accuracy: 0.0469
# Batch no: 016, Loss on trainig: 4.4807, Accuracy: 0.0781
# Batch no: 017, Loss on trainig: 4.5175, Accuracy: 0.0469
# Batch no: 018, Loss on trainig: 4.6795, Accuracy: 0.0469
# Batch no: 019, Loss on trainig: 4.5448, Accuracy: 0.0156
# Batch no: 020, Loss on trainig: 4.5909, Accuracy: 0.0312
# Batch no: 021, Loss on trainig: 4.5329, Accuracy: 0.0469
# Batch no: 022, Loss on trainig: 4.5277, Accuracy: 0.0312
# Batch no: 023, Loss on trainig: 4.5305, Accuracy: 0.0156
# Batch no: 024, Loss on trainig: 4.6087, Accuracy: 0.0312
# Batch no: 025, Loss on trainig: 4.4479, Accuracy: 0.0625
# Batch no: 026, Loss on trainig: 4.4615, Accuracy: 0.0469
# Batch no: 027, Loss on trainig: 4.2871, Accuracy: 0.0625
# Batch no: 028, Loss on trainig: 4.5230, Accuracy: 0.0625
# Batch no: 029, Loss on trainig: 4.4071, Accuracy: 0.0625
# Batch no: 030, Loss on trainig: 4.3452, Accuracy: 0.1094
# Batch no: 031, Loss on trainig: 4.1659, Accuracy: 0.1094
# Batch no: 032, Loss on trainig: 4.4238, Accuracy: 0.0781
# Batch no: 033, Loss on trainig: 4.3511, Accuracy: 0.0781
# Batch no: 034, Loss on trainig: 4.4673, Accuracy: 0.0312
# Batch no: 035, Loss on trainig: 4.3566, Accuracy: 0.0938
# Batch no: 036, Loss on trainig: 4.3894, Accuracy: 0.1094
# Batch no: 037, Loss on trainig: 4.4364, Accuracy: 0.0469
# Batch no: 038, Loss on trainig: 4.3319, Accuracy: 0.1094
# Batch no: 039, Loss on trainig: 4.4564, Accuracy: 0.0469
# Batch no: 040, Loss on trainig: 4.2623, Accuracy: 0.0781
# Batch no: 041, Loss on trainig: 4.2042, Accuracy: 0.0938
# Batch no: 042, Loss on trainig: 4.3110, Accuracy: 0.0469
# Batch no: 043, Loss on trainig: 4.2747, Accuracy: 0.0938
# Batch no: 044, Loss on trainig: 4.2493, Accuracy: 0.0625
# Batch no: 045, Loss on trainig: 4.1230, Accuracy: 0.0312
# Batch no: 046, Loss on trainig: 4.1671, Accuracy: 0.0781
# Batch no: 047, Loss on trainig: 4.1369, Accuracy: 0.1250
# Batch no: 048, Loss on trainig: 4.1310, Accuracy: 0.1250
# Batch no: 049, Loss on trainig: 4.0140, Accuracy: 0.1250
# Batch no: 050, Loss on trainig: 4.1319, Accuracy: 0.1250
# Batch no: 051, Loss on trainig: 4.0427, Accuracy: 0.1719
# Batch no: 052, Loss on trainig: 4.0978, Accuracy: 0.1094
# Batch no: 053, Loss on trainig: 4.3961, Accuracy: 0.0938
# Batch no: 054, Loss on trainig: 3.9586, Accuracy: 0.1719
# Batch no: 055, Loss on trainig: 4.1834, Accuracy: 0.0469
# Batch no: 056, Loss on trainig: 3.8401, Accuracy: 0.1250
# Batch no: 057, Loss on trainig: 3.8783, Accuracy: 0.1562
# Batch no: 058, Loss on trainig: 4.1074, Accuracy: 0.1562
# Batch no: 059, Loss on trainig: 3.8968, Accuracy: 0.1406
# Batch no: 060, Loss on trainig: 3.7714, Accuracy: 0.1875
# Batch no: 061, Loss on trainig: 3.8020, Accuracy: 0.1875
# Batch no: 062, Loss on trainig: 3.8094, Accuracy: 0.2031
# Batch no: 063, Loss on trainig: 4.0340, Accuracy: 0.0781
# Batch no: 064, Loss on trainig: 3.7910, Accuracy: 0.1406
# Batch no: 065, Loss on trainig: 3.9699, Accuracy: 0.1094
# Batch no: 066, Loss on trainig: 3.9944, Accuracy: 0.1562
# Batch no: 067, Loss on trainig: 3.8255, Accuracy: 0.1562
# Batch no: 068, Loss on trainig: 4.0591, Accuracy: 0.1094
# Batch no: 069, Loss on trainig: 3.8236, Accuracy: 0.1719
# Batch no: 070, Loss on trainig: 3.9051, Accuracy: 0.1250
# Batch no: 071, Loss on trainig: 3.6957, Accuracy: 0.1406
# Batch no: 072, Loss on trainig: 3.6542, Accuracy: 0.1562
# Batch no: 073, Loss on trainig: 3.8663, Accuracy: 0.1094
# Batch no: 074, Loss on trainig: 3.6534, Accuracy: 0.1719
# Batch no: 075, Loss on trainig: 3.5590, Accuracy: 0.1094
# Batch no: 076, Loss on trainig: 3.7100, Accuracy: 0.1875
# Batch no: 077, Loss on trainig: 4.0595, Accuracy: 0.0625
# Batch no: 078, Loss on trainig: 3.2490, Accuracy: 0.2656
# Batch no: 079, Loss on trainig: 3.6861, Accuracy: 0.1250
# Batch no: 080, Loss on trainig: 3.7674, Accuracy: 0.1875
# Batch no: 081, Loss on trainig: 3.6368, Accuracy: 0.0938
# Batch no: 082, Loss on trainig: 3.7499, Accuracy: 0.1250
# Batch no: 083, Loss on trainig: 3.5492, Accuracy: 0.1719
# Batch no: 084, Loss on trainig: 3.6394, Accuracy: 0.1562
# Batch no: 085, Loss on trainig: 3.6248, Accuracy: 0.1719
# Batch no: 086, Loss on trainig: 3.6546, Accuracy: 0.1719
# Batch no: 087, Loss on trainig: 3.4350, Accuracy: 0.2500
# Batch no: 088, Loss on trainig: 3.3864, Accuracy: 0.2188
# Batch no: 089, Loss on trainig: 3.4285, Accuracy: 0.2344
# Batch no: 090, Loss on trainig: 3.6017, Accuracy: 0.1875
# Batch no: 091, Loss on trainig: 3.4610, Accuracy: 0.2031
# Batch no: 092, Loss on trainig: 3.4830, Accuracy: 0.2500
# Batch no: 093, Loss on trainig: 3.5909, Accuracy: 0.2188
# Batch no: 094, Loss on trainig: 3.4974, Accuracy: 0.1875
# Batch no: 095, Loss on trainig: 3.0800, Accuracy: 0.2812
# Batch no: 096, Loss on trainig: 3.5153, Accuracy: 0.2344
# Batch no: 097, Loss on trainig: 3.3422, Accuracy: 0.1719
# Batch no: 098, Loss on trainig: 3.3480, Accuracy: 0.1875
# Batch no: 099, Loss on trainig: 3.1515, Accuracy: 0.3281
# Batch no: 100, Loss on trainig: 3.4996, Accuracy: 0.1875
# Batch no: 101, Loss on trainig: 3.6115, Accuracy: 0.1875
# Batch no: 102, Loss on trainig: 3.0175, Accuracy: 0.3333
# Epoch: 2/19
# Batch no: 000, Loss on trainig: 3.4432, Accuracy: 0.1406
# Batch no: 001, Loss on trainig: 3.2650, Accuracy: 0.2344
# Batch no: 002, Loss on trainig: 3.1325, Accuracy: 0.2812
# Batch no: 003, Loss on trainig: 3.6693, Accuracy: 0.1250
# Batch no: 004, Loss on trainig: 3.1927, Accuracy: 0.2656
# Batch no: 005, Loss on trainig: 3.0222, Accuracy: 0.2344
# Batch no: 006, Loss on trainig: 3.3352, Accuracy: 0.1875
# Batch no: 007, Loss on trainig: 3.0084, Accuracy: 0.2344
# Batch no: 008, Loss on trainig: 3.1047, Accuracy: 0.2500
# Batch no: 009, Loss on trainig: 3.0342, Accuracy: 0.2656
# Batch no: 010, Loss on trainig: 3.2970, Accuracy: 0.2500
# Batch no: 011, Loss on trainig: 3.1181, Accuracy: 0.2344
# Batch no: 012, Loss on trainig: 2.6760, Accuracy: 0.3281
# Batch no: 013, Loss on trainig: 2.8550, Accuracy: 0.2656
# Batch no: 014, Loss on trainig: 3.0037, Accuracy: 0.2656
# Batch no: 015, Loss on trainig: 3.1295, Accuracy: 0.2188
# Batch no: 016, Loss on trainig: 3.2323, Accuracy: 0.2344
# Batch no: 017, Loss on trainig: 3.2802, Accuracy: 0.2344
# Batch no: 018, Loss on trainig: 2.8375, Accuracy: 0.2656
# Batch no: 019, Loss on trainig: 3.0392, Accuracy: 0.2812
# Batch no: 020, Loss on trainig: 3.0007, Accuracy: 0.2500
# Batch no: 021, Loss on trainig: 3.0315, Accuracy: 0.2656
# Batch no: 022, Loss on trainig: 3.3355, Accuracy: 0.2344
# Batch no: 023, Loss on trainig: 3.2039, Accuracy: 0.2812
# Batch no: 024, Loss on trainig: 3.4470, Accuracy: 0.1875
# Batch no: 025, Loss on trainig: 2.9023, Accuracy: 0.2812
# Batch no: 026, Loss on trainig: 2.6925, Accuracy: 0.3125
# Batch no: 027, Loss on trainig: 3.1094, Accuracy: 0.2500
# Batch no: 028, Loss on trainig: 3.1305, Accuracy: 0.2969
# Batch no: 029, Loss on trainig: 3.1062, Accuracy: 0.2656
# Batch no: 030, Loss on trainig: 2.9797, Accuracy: 0.2656
# Batch no: 031, Loss on trainig: 2.8218, Accuracy: 0.2969
# Batch no: 032, Loss on trainig: 2.9631, Accuracy: 0.2188
# Batch no: 033, Loss on trainig: 2.8091, Accuracy: 0.2656
# Batch no: 034, Loss on trainig: 2.9984, Accuracy: 0.1719
# Batch no: 035, Loss on trainig: 2.7997, Accuracy: 0.2969
# Batch no: 036, Loss on trainig: 2.9404, Accuracy: 0.2031
# Batch no: 037, Loss on trainig: 2.7286, Accuracy: 0.3281
# Batch no: 038, Loss on trainig: 3.0793, Accuracy: 0.2812
# Batch no: 039, Loss on trainig: 3.3871, Accuracy: 0.2031
# Batch no: 040, Loss on trainig: 3.0882, Accuracy: 0.2812
# Batch no: 041, Loss on trainig: 2.5675, Accuracy: 0.3125
# Batch no: 042, Loss on trainig: 2.5281, Accuracy: 0.2969
# Batch no: 043, Loss on trainig: 2.9487, Accuracy: 0.2188
# Batch no: 044, Loss on trainig: 2.7649, Accuracy: 0.3281
# Batch no: 045, Loss on trainig: 2.8729, Accuracy: 0.2812
# Batch no: 046, Loss on trainig: 2.6222, Accuracy: 0.3438
# Batch no: 047, Loss on trainig: 2.8633, Accuracy: 0.4219
# Batch no: 048, Loss on trainig: 2.6593, Accuracy: 0.3594
# Batch no: 049, Loss on trainig: 2.4238, Accuracy: 0.4219
# Batch no: 050, Loss on trainig: 2.7718, Accuracy: 0.2031
# Batch no: 051, Loss on trainig: 2.5643, Accuracy: 0.3750
# Batch no: 052, Loss on trainig: 2.7719, Accuracy: 0.2656
# Batch no: 053, Loss on trainig: 2.9461, Accuracy: 0.2500
# Batch no: 054, Loss on trainig: 2.5746, Accuracy: 0.4062
# Batch no: 055, Loss on trainig: 2.4354, Accuracy: 0.3906
# Batch no: 056, Loss on trainig: 2.3851, Accuracy: 0.4844
# Batch no: 057, Loss on trainig: 2.9840, Accuracy: 0.2500
# Batch no: 058, Loss on trainig: 3.0571, Accuracy: 0.2188
# Batch no: 059, Loss on trainig: 2.8206, Accuracy: 0.3125
# Batch no: 060, Loss on trainig: 2.8485, Accuracy: 0.2656
# Batch no: 061, Loss on trainig: 2.6594, Accuracy: 0.3281
# Batch no: 062, Loss on trainig: 2.6046, Accuracy: 0.3281
# Batch no: 063, Loss on trainig: 3.0145, Accuracy: 0.2656
# Batch no: 064, Loss on trainig: 2.5578, Accuracy: 0.3594
# Batch no: 065, Loss on trainig: 2.6650, Accuracy: 0.3281
# Batch no: 066, Loss on trainig: 3.0443, Accuracy: 0.2031
# Batch no: 067, Loss on trainig: 2.5254, Accuracy: 0.3438
# Batch no: 068, Loss on trainig: 2.7196, Accuracy: 0.2969
# Batch no: 069, Loss on trainig: 2.9377, Accuracy: 0.2344
# Batch no: 070, Loss on trainig: 2.6343, Accuracy: 0.2500
# Batch no: 071, Loss on trainig: 2.6381, Accuracy: 0.2656
# Batch no: 072, Loss on trainig: 2.6176, Accuracy: 0.3281
# Batch no: 073, Loss on trainig: 2.9707, Accuracy: 0.2812
# Batch no: 074, Loss on trainig: 2.4019, Accuracy: 0.3906
# Batch no: 075, Loss on trainig: 3.0273, Accuracy: 0.2188
# Batch no: 076, Loss on trainig: 2.9670, Accuracy: 0.2500
# Batch no: 077, Loss on trainig: 2.7571, Accuracy: 0.3594
# Batch no: 078, Loss on trainig: 2.3462, Accuracy: 0.4688
# Batch no: 079, Loss on trainig: 2.7026, Accuracy: 0.3281
# Batch no: 080, Loss on trainig: 2.8596, Accuracy: 0.2969
# Batch no: 081, Loss on trainig: 3.0090, Accuracy: 0.2344
# Batch no: 082, Loss on trainig: 2.7913, Accuracy: 0.3594
# Batch no: 083, Loss on trainig: 2.8131, Accuracy: 0.2500
# Batch no: 084, Loss on trainig: 2.8499, Accuracy: 0.2969
# Batch no: 085, Loss on trainig: 2.7545, Accuracy: 0.2656
# Batch no: 086, Loss on trainig: 2.2965, Accuracy: 0.4375
# Batch no: 087, Loss on trainig: 2.3047, Accuracy: 0.4531
# Batch no: 088, Loss on trainig: 2.6080, Accuracy: 0.3125
# Batch no: 089, Loss on trainig: 2.5989, Accuracy: 0.3594
# Batch no: 090, Loss on trainig: 2.5035, Accuracy: 0.4375
# Batch no: 091, Loss on trainig: 2.3846, Accuracy: 0.3750
# Batch no: 092, Loss on trainig: 2.6709, Accuracy: 0.2812
# Batch no: 093, Loss on trainig: 2.8350, Accuracy: 0.2656
# Batch no: 094, Loss on trainig: 2.8185, Accuracy: 0.3438
# Batch no: 095, Loss on trainig: 2.5676, Accuracy: 0.2500
# Batch no: 096, Loss on trainig: 2.3058, Accuracy: 0.4219
# Batch no: 097, Loss on trainig: 2.4161, Accuracy: 0.4062
# Batch no: 098, Loss on trainig: 2.8901, Accuracy: 0.2500
# Batch no: 099, Loss on trainig: 2.6770, Accuracy: 0.3438
# Batch no: 100, Loss on trainig: 2.3551, Accuracy: 0.3750
# Batch no: 101, Loss on trainig: 2.7740, Accuracy: 0.2656
# Batch no: 102, Loss on trainig: 2.2692, Accuracy: 0.3750
# Epoch: 3/19
# Batch no: 000, Loss on trainig: 2.5432, Accuracy: 0.2969
# Batch no: 001, Loss on trainig: 2.5911, Accuracy: 0.3750
# Batch no: 002, Loss on trainig: 2.5052, Accuracy: 0.3594
# Batch no: 003, Loss on trainig: 2.1154, Accuracy: 0.4062
# Batch no: 004, Loss on trainig: 2.1795, Accuracy: 0.3594
# Batch no: 005, Loss on trainig: 2.2205, Accuracy: 0.3750
# Batch no: 006, Loss on trainig: 2.5736, Accuracy: 0.3281
# Batch no: 007, Loss on trainig: 2.2905, Accuracy: 0.3750
# Batch no: 008, Loss on trainig: 2.1417, Accuracy: 0.4375
# Batch no: 009, Loss on trainig: 2.9119, Accuracy: 0.2656
# Batch no: 010, Loss on trainig: 2.0635, Accuracy: 0.5000
# Batch no: 011, Loss on trainig: 2.4507, Accuracy: 0.4219
# Batch no: 012, Loss on trainig: 2.5987, Accuracy: 0.2969
# Batch no: 013, Loss on trainig: 2.2766, Accuracy: 0.4219
# Batch no: 014, Loss on trainig: 2.2688, Accuracy: 0.3906
# Batch no: 015, Loss on trainig: 2.1388, Accuracy: 0.4375
# Batch no: 016, Loss on trainig: 2.5861, Accuracy: 0.3125
# Batch no: 017, Loss on trainig: 2.2398, Accuracy: 0.4219
# Batch no: 018, Loss on trainig: 2.4917, Accuracy: 0.3750
# Batch no: 019, Loss on trainig: 2.3145, Accuracy: 0.3906
# Batch no: 020, Loss on trainig: 2.6072, Accuracy: 0.3125
# Batch no: 021, Loss on trainig: 2.3046, Accuracy: 0.4531
# Batch no: 022, Loss on trainig: 2.3649, Accuracy: 0.4219
# Batch no: 023, Loss on trainig: 2.5688, Accuracy: 0.3438
# Batch no: 024, Loss on trainig: 2.6878, Accuracy: 0.2812
# Batch no: 025, Loss on trainig: 2.5615, Accuracy: 0.3438
# Batch no: 026, Loss on trainig: 2.4652, Accuracy: 0.3594
# Batch no: 027, Loss on trainig: 2.7253, Accuracy: 0.2656
# Batch no: 028, Loss on trainig: 1.9642, Accuracy: 0.4062
# Batch no: 029, Loss on trainig: 2.4428, Accuracy: 0.3125
# Batch no: 030, Loss on trainig: 2.4724, Accuracy: 0.3594
# Batch no: 031, Loss on trainig: 2.6574, Accuracy: 0.3438
# Batch no: 032, Loss on trainig: 2.3100, Accuracy: 0.3750
# Batch no: 033, Loss on trainig: 2.4545, Accuracy: 0.3750
# Batch no: 034, Loss on trainig: 2.5649, Accuracy: 0.3594
# Batch no: 035, Loss on trainig: 2.4734, Accuracy: 0.3906
# Batch no: 036, Loss on trainig: 2.3484, Accuracy: 0.4531
# Batch no: 037, Loss on trainig: 1.9428, Accuracy: 0.4688
# Batch no: 038, Loss on trainig: 2.2384, Accuracy: 0.3750
# Batch no: 039, Loss on trainig: 2.5420, Accuracy: 0.3438
# Batch no: 040, Loss on trainig: 2.4032, Accuracy: 0.4219
# Batch no: 041, Loss on trainig: 2.3319, Accuracy: 0.3594
# Batch no: 042, Loss on trainig: 2.1764, Accuracy: 0.3906
# Batch no: 043, Loss on trainig: 2.7031, Accuracy: 0.3594
# Batch no: 044, Loss on trainig: 2.1300, Accuracy: 0.4219
# Batch no: 045, Loss on trainig: 2.4449, Accuracy: 0.4062
# Batch no: 046, Loss on trainig: 2.4880, Accuracy: 0.4219
# Batch no: 047, Loss on trainig: 2.3542, Accuracy: 0.3906
# Batch no: 048, Loss on trainig: 2.3234, Accuracy: 0.3750
# Batch no: 049, Loss on trainig: 2.7355, Accuracy: 0.3750
# Batch no: 050, Loss on trainig: 1.7865, Accuracy: 0.5312
# Batch no: 051, Loss on trainig: 2.4949, Accuracy: 0.3281
# Batch no: 052, Loss on trainig: 2.1381, Accuracy: 0.4219
# Batch no: 053, Loss on trainig: 2.5512, Accuracy: 0.4062
# Batch no: 054, Loss on trainig: 2.2512, Accuracy: 0.4531
# Batch no: 055, Loss on trainig: 2.4405, Accuracy: 0.3438
# Batch no: 056, Loss on trainig: 2.3592, Accuracy: 0.3438
# Batch no: 057, Loss on trainig: 2.3851, Accuracy: 0.2969
# Batch no: 058, Loss on trainig: 2.5345, Accuracy: 0.3281
# Batch no: 059, Loss on trainig: 2.2244, Accuracy: 0.3906
# Batch no: 060, Loss on trainig: 2.3388, Accuracy: 0.4219
# Batch no: 061, Loss on trainig: 1.8953, Accuracy: 0.5312
# Batch no: 062, Loss on trainig: 2.2299, Accuracy: 0.3281
# Batch no: 063, Loss on trainig: 2.3007, Accuracy: 0.3906
# Batch no: 064, Loss on trainig: 2.4575, Accuracy: 0.3594
# Batch no: 065, Loss on trainig: 2.4271, Accuracy: 0.3906
# Batch no: 066, Loss on trainig: 2.3982, Accuracy: 0.3438
# Batch no: 067, Loss on trainig: 2.2782, Accuracy: 0.4375
# Batch no: 068, Loss on trainig: 2.1890, Accuracy: 0.3750
# Batch no: 069, Loss on trainig: 2.0144, Accuracy: 0.4688
# Batch no: 070, Loss on trainig: 2.4207, Accuracy: 0.3750
# Batch no: 071, Loss on trainig: 2.2252, Accuracy: 0.3594
# Batch no: 072, Loss on trainig: 2.1913, Accuracy: 0.4375
# Batch no: 073, Loss on trainig: 2.3470, Accuracy: 0.4375
# Batch no: 074, Loss on trainig: 2.3099, Accuracy: 0.3906
# Batch no: 075, Loss on trainig: 2.1529, Accuracy: 0.4219
# Batch no: 076, Loss on trainig: 2.1352, Accuracy: 0.3281
# Batch no: 077, Loss on trainig: 2.3379, Accuracy: 0.3438
# Batch no: 078, Loss on trainig: 2.6618, Accuracy: 0.2500
# Batch no: 079, Loss on trainig: 1.9933, Accuracy: 0.4375
# Batch no: 080, Loss on trainig: 2.4119, Accuracy: 0.3906
# Batch no: 081, Loss on trainig: 2.3720, Accuracy: 0.2969
# Batch no: 082, Loss on trainig: 2.4817, Accuracy: 0.3594
# Batch no: 083, Loss on trainig: 2.3337, Accuracy: 0.3750
# Batch no: 084, Loss on trainig: 2.2939, Accuracy: 0.3594
# Batch no: 085, Loss on trainig: 2.2133, Accuracy: 0.4062
# Batch no: 086, Loss on trainig: 2.2143, Accuracy: 0.3750
# Batch no: 087, Loss on trainig: 2.3461, Accuracy: 0.3750
# Batch no: 088, Loss on trainig: 2.2821, Accuracy: 0.4375
# Batch no: 089, Loss on trainig: 2.2385, Accuracy: 0.4375
# Batch no: 090, Loss on trainig: 2.6249, Accuracy: 0.2500
# Batch no: 091, Loss on trainig: 2.2190, Accuracy: 0.4844
# Batch no: 092, Loss on trainig: 2.1545, Accuracy: 0.4062
# Batch no: 093, Loss on trainig: 1.9192, Accuracy: 0.5625
# Batch no: 094, Loss on trainig: 2.2206, Accuracy: 0.5000
# Batch no: 095, Loss on trainig: 2.5053, Accuracy: 0.3438
# Batch no: 096, Loss on trainig: 2.1103, Accuracy: 0.3281
# Batch no: 097, Loss on trainig: 2.0024, Accuracy: 0.4062
# Batch no: 098, Loss on trainig: 2.0760, Accuracy: 0.4375
# Batch no: 099, Loss on trainig: 1.8920, Accuracy: 0.4688
# Batch no: 100, Loss on trainig: 2.2361, Accuracy: 0.5156
# Batch no: 101, Loss on trainig: 1.9530, Accuracy: 0.3906
# Batch no: 102, Loss on trainig: 2.2843, Accuracy: 0.3333
# Epoch: 4/19
# Batch no: 000, Loss on trainig: 2.3685, Accuracy: 0.3594
# Batch no: 001, Loss on trainig: 2.1516, Accuracy: 0.4219
# Batch no: 002, Loss on trainig: 2.2717, Accuracy: 0.4062
# Batch no: 003, Loss on trainig: 2.4504, Accuracy: 0.2500
# Batch no: 004, Loss on trainig: 1.9122, Accuracy: 0.5000
# Batch no: 005, Loss on trainig: 2.1559, Accuracy: 0.5000
# Batch no: 006, Loss on trainig: 2.2486, Accuracy: 0.4219
# Batch no: 007, Loss on trainig: 2.0619, Accuracy: 0.4219
# Batch no: 008, Loss on trainig: 1.9697, Accuracy: 0.3594
# Batch no: 009, Loss on trainig: 2.2390, Accuracy: 0.4688
# Batch no: 010, Loss on trainig: 1.9580, Accuracy: 0.4219
# Batch no: 011, Loss on trainig: 2.2247, Accuracy: 0.4062
# Batch no: 012, Loss on trainig: 2.6422, Accuracy: 0.3125
# Batch no: 013, Loss on trainig: 2.3262, Accuracy: 0.3594
# Batch no: 014, Loss on trainig: 2.4996, Accuracy: 0.3281
# Batch no: 015, Loss on trainig: 2.2507, Accuracy: 0.3906
# Batch no: 016, Loss on trainig: 1.9707, Accuracy: 0.4844
# Batch no: 017, Loss on trainig: 2.0630, Accuracy: 0.3906
# Batch no: 018, Loss on trainig: 2.2033, Accuracy: 0.3750
# Batch no: 019, Loss on trainig: 1.7904, Accuracy: 0.5312
# Batch no: 020, Loss on trainig: 2.2777, Accuracy: 0.4062
# Batch no: 021, Loss on trainig: 1.8098, Accuracy: 0.5625
# Batch no: 022, Loss on trainig: 2.4922, Accuracy: 0.3594
# Batch no: 023, Loss on trainig: 2.0004, Accuracy: 0.4219
# Batch no: 024, Loss on trainig: 2.2311, Accuracy: 0.4219
# Batch no: 025, Loss on trainig: 1.8359, Accuracy: 0.4375
# Batch no: 026, Loss on trainig: 2.0254, Accuracy: 0.4219
# Batch no: 027, Loss on trainig: 1.9808, Accuracy: 0.4531
# Batch no: 028, Loss on trainig: 2.2082, Accuracy: 0.4375
# Batch no: 029, Loss on trainig: 2.2158, Accuracy: 0.4219
# Batch no: 030, Loss on trainig: 2.2093, Accuracy: 0.4844
# Batch no: 031, Loss on trainig: 2.1951, Accuracy: 0.4531
# Batch no: 032, Loss on trainig: 2.1193, Accuracy: 0.3438
# Batch no: 033, Loss on trainig: 1.9803, Accuracy: 0.5156
# Batch no: 034, Loss on trainig: 2.1403, Accuracy: 0.3906
# Batch no: 035, Loss on trainig: 1.8649, Accuracy: 0.4688
# Batch no: 036, Loss on trainig: 1.9841, Accuracy: 0.4688
# Batch no: 037, Loss on trainig: 1.9926, Accuracy: 0.4219
# Batch no: 038, Loss on trainig: 2.3326, Accuracy: 0.3125
# Batch no: 039, Loss on trainig: 1.9012, Accuracy: 0.5156
# Batch no: 040, Loss on trainig: 1.9618, Accuracy: 0.3750
# Batch no: 041, Loss on trainig: 1.8036, Accuracy: 0.5156
# Batch no: 042, Loss on trainig: 2.0158, Accuracy: 0.4375
# Batch no: 043, Loss on trainig: 2.1982, Accuracy: 0.4219
# Batch no: 044, Loss on trainig: 2.2325, Accuracy: 0.3281
# Batch no: 045, Loss on trainig: 2.3513, Accuracy: 0.3906
# Batch no: 046, Loss on trainig: 1.8756, Accuracy: 0.4844
# Batch no: 047, Loss on trainig: 2.0323, Accuracy: 0.3750
# Batch no: 048, Loss on trainig: 1.6587, Accuracy: 0.6094
# Batch no: 049, Loss on trainig: 2.2420, Accuracy: 0.4062
# Batch no: 050, Loss on trainig: 2.2750, Accuracy: 0.4062
# Batch no: 051, Loss on trainig: 1.8421, Accuracy: 0.5469
# Batch no: 052, Loss on trainig: 1.8529, Accuracy: 0.5312
# Batch no: 053, Loss on trainig: 2.0530, Accuracy: 0.4219
# Batch no: 054, Loss on trainig: 2.0070, Accuracy: 0.4062
# Batch no: 055, Loss on trainig: 2.2581, Accuracy: 0.4062
# Batch no: 056, Loss on trainig: 2.1343, Accuracy: 0.4375
# Batch no: 057, Loss on trainig: 2.0468, Accuracy: 0.3906
# Batch no: 058, Loss on trainig: 2.0040, Accuracy: 0.4531
# Batch no: 059, Loss on trainig: 1.9746, Accuracy: 0.3594
# Batch no: 060, Loss on trainig: 1.9503, Accuracy: 0.4531
# Batch no: 061, Loss on trainig: 2.0627, Accuracy: 0.3594
# Batch no: 062, Loss on trainig: 2.1184, Accuracy: 0.3906
# Batch no: 063, Loss on trainig: 2.1513, Accuracy: 0.4219
# Batch no: 064, Loss on trainig: 2.3298, Accuracy: 0.3594
# Batch no: 065, Loss on trainig: 2.0751, Accuracy: 0.4375
# Batch no: 066, Loss on trainig: 2.1613, Accuracy: 0.3906
# Batch no: 067, Loss on trainig: 2.3226, Accuracy: 0.4062
# Batch no: 068, Loss on trainig: 2.0866, Accuracy: 0.5000
# Batch no: 069, Loss on trainig: 2.3425, Accuracy: 0.4062
# Batch no: 070, Loss on trainig: 2.2042, Accuracy: 0.4531
# Batch no: 071, Loss on trainig: 1.6530, Accuracy: 0.5312
# Batch no: 072, Loss on trainig: 1.9327, Accuracy: 0.4375
# Batch no: 073, Loss on trainig: 2.0765, Accuracy: 0.4375
# Batch no: 074, Loss on trainig: 1.9684, Accuracy: 0.4219
# Batch no: 075, Loss on trainig: 1.8573, Accuracy: 0.4844
# Batch no: 076, Loss on trainig: 2.0962, Accuracy: 0.4531
# Batch no: 077, Loss on trainig: 2.2839, Accuracy: 0.3281
# Batch no: 078, Loss on trainig: 1.8217, Accuracy: 0.5312
# Batch no: 079, Loss on trainig: 1.9352, Accuracy: 0.4531
# Batch no: 080, Loss on trainig: 2.2121, Accuracy: 0.3438
# Batch no: 081, Loss on trainig: 2.3491, Accuracy: 0.4062
# Batch no: 082, Loss on trainig: 2.1584, Accuracy: 0.3906
# Batch no: 083, Loss on trainig: 2.2606, Accuracy: 0.3750
# Batch no: 084, Loss on trainig: 2.3956, Accuracy: 0.4375
# Batch no: 085, Loss on trainig: 1.9471, Accuracy: 0.4375
# Batch no: 086, Loss on trainig: 1.6386, Accuracy: 0.5469
# Batch no: 087, Loss on trainig: 2.0030, Accuracy: 0.4219
# Batch no: 088, Loss on trainig: 1.9150, Accuracy: 0.5156
# Batch no: 089, Loss on trainig: 2.3988, Accuracy: 0.3906
# Batch no: 090, Loss on trainig: 2.2011, Accuracy: 0.4219
# Batch no: 091, Loss on trainig: 2.1143, Accuracy: 0.4219
# Batch no: 092, Loss on trainig: 1.9832, Accuracy: 0.4062
# Batch no: 093, Loss on trainig: 1.6439, Accuracy: 0.5312
# Batch no: 094, Loss on trainig: 1.9382, Accuracy: 0.4844
# Batch no: 095, Loss on trainig: 1.8719, Accuracy: 0.4062
# Batch no: 096, Loss on trainig: 2.0439, Accuracy: 0.4375
# Batch no: 097, Loss on trainig: 1.6685, Accuracy: 0.5000
# Batch no: 098, Loss on trainig: 1.8539, Accuracy: 0.4844
# Batch no: 099, Loss on trainig: 1.9901, Accuracy: 0.4531
# Batch no: 100, Loss on trainig: 2.1789, Accuracy: 0.4688
# Batch no: 101, Loss on trainig: 2.1265, Accuracy: 0.3594
# Batch no: 102, Loss on trainig: 2.9394, Accuracy: 0.2500
# Epoch: 5/19
# Batch no: 000, Loss on trainig: 2.1789, Accuracy: 0.4219
# Batch no: 001, Loss on trainig: 2.0285, Accuracy: 0.4531
# Batch no: 002, Loss on trainig: 2.0928, Accuracy: 0.4531
# Batch no: 003, Loss on trainig: 1.7756, Accuracy: 0.5938
# Batch no: 004, Loss on trainig: 1.9975, Accuracy: 0.3906
# Batch no: 005, Loss on trainig: 1.8742, Accuracy: 0.5469
# Batch no: 006, Loss on trainig: 1.5394, Accuracy: 0.6094
# Batch no: 007, Loss on trainig: 2.1426, Accuracy: 0.4219
# Batch no: 008, Loss on trainig: 1.8266, Accuracy: 0.5156
# Batch no: 009, Loss on trainig: 2.1445, Accuracy: 0.3750
# Batch no: 010, Loss on trainig: 1.8511, Accuracy: 0.4062
# Batch no: 011, Loss on trainig: 1.9615, Accuracy: 0.5625
# Batch no: 012, Loss on trainig: 2.0259, Accuracy: 0.4531
# Batch no: 013, Loss on trainig: 2.0549, Accuracy: 0.4688
# Batch no: 014, Loss on trainig: 2.0710, Accuracy: 0.4688
# Batch no: 015, Loss on trainig: 1.9727, Accuracy: 0.4531
# Batch no: 016, Loss on trainig: 1.8799, Accuracy: 0.4688
# Batch no: 017, Loss on trainig: 1.7517, Accuracy: 0.5000
# Batch no: 018, Loss on trainig: 1.8485, Accuracy: 0.4844
# Batch no: 019, Loss on trainig: 2.1477, Accuracy: 0.4531
# Batch no: 020, Loss on trainig: 1.8002, Accuracy: 0.5000
# Batch no: 021, Loss on trainig: 2.0061, Accuracy: 0.4062
# Batch no: 022, Loss on trainig: 2.0940, Accuracy: 0.4531
# Batch no: 023, Loss on trainig: 1.8434, Accuracy: 0.5156
# Batch no: 024, Loss on trainig: 1.5910, Accuracy: 0.5938
# Batch no: 025, Loss on trainig: 2.1681, Accuracy: 0.4219
# Batch no: 026, Loss on trainig: 1.9764, Accuracy: 0.4375
# Batch no: 027, Loss on trainig: 2.0026, Accuracy: 0.5000
# Batch no: 028, Loss on trainig: 2.4278, Accuracy: 0.3906
# Batch no: 029, Loss on trainig: 1.7118, Accuracy: 0.5469
# Batch no: 030, Loss on trainig: 2.4363, Accuracy: 0.4062
# Batch no: 031, Loss on trainig: 2.3449, Accuracy: 0.4375
# Batch no: 032, Loss on trainig: 1.9344, Accuracy: 0.4844
# Batch no: 033, Loss on trainig: 1.6336, Accuracy: 0.5781
# Batch no: 034, Loss on trainig: 2.1964, Accuracy: 0.3750
# Batch no: 035, Loss on trainig: 1.9265, Accuracy: 0.5156
# Batch no: 036, Loss on trainig: 1.6615, Accuracy: 0.5156
# Batch no: 037, Loss on trainig: 2.2686, Accuracy: 0.3750
# Batch no: 038, Loss on trainig: 2.2574, Accuracy: 0.4219
# Batch no: 039, Loss on trainig: 1.9609, Accuracy: 0.5000
# Batch no: 040, Loss on trainig: 1.4572, Accuracy: 0.6250
# Batch no: 041, Loss on trainig: 2.0325, Accuracy: 0.4688
# Batch no: 042, Loss on trainig: 2.0175, Accuracy: 0.4688
# Batch no: 043, Loss on trainig: 2.2114, Accuracy: 0.4688
# Batch no: 044, Loss on trainig: 1.6713, Accuracy: 0.5000
# Batch no: 045, Loss on trainig: 1.6710, Accuracy: 0.5625
# Batch no: 046, Loss on trainig: 1.9412, Accuracy: 0.5000
# Batch no: 047, Loss on trainig: 1.9414, Accuracy: 0.5469
# Batch no: 048, Loss on trainig: 1.7488, Accuracy: 0.5000
# Batch no: 049, Loss on trainig: 1.8772, Accuracy: 0.5000
# Batch no: 050, Loss on trainig: 1.9628, Accuracy: 0.3594
# Batch no: 051, Loss on trainig: 1.9483, Accuracy: 0.5000
# Batch no: 052, Loss on trainig: 2.1361, Accuracy: 0.4062
# Batch no: 053, Loss on trainig: 1.8752, Accuracy: 0.4688
# Batch no: 054, Loss on trainig: 2.2344, Accuracy: 0.3906
# Batch no: 055, Loss on trainig: 1.9651, Accuracy: 0.4688
# Batch no: 056, Loss on trainig: 2.0139, Accuracy: 0.4688
# Batch no: 057, Loss on trainig: 2.0369, Accuracy: 0.4844
# Batch no: 058, Loss on trainig: 1.7180, Accuracy: 0.5156
# Batch no: 059, Loss on trainig: 1.7466, Accuracy: 0.4375
# Batch no: 060, Loss on trainig: 1.8866, Accuracy: 0.4688
# Batch no: 061, Loss on trainig: 1.8284, Accuracy: 0.5625
# Batch no: 062, Loss on trainig: 1.9562, Accuracy: 0.4844
# Batch no: 063, Loss on trainig: 2.0752, Accuracy: 0.5156
# Batch no: 064, Loss on trainig: 1.8748, Accuracy: 0.5469
# Batch no: 065, Loss on trainig: 2.1285, Accuracy: 0.4688
# Batch no: 066, Loss on trainig: 1.8053, Accuracy: 0.4844
# Batch no: 067, Loss on trainig: 1.9248, Accuracy: 0.5312
# Batch no: 068, Loss on trainig: 2.2406, Accuracy: 0.3594
# Batch no: 069, Loss on trainig: 1.9825, Accuracy: 0.5156
# Batch no: 070, Loss on trainig: 1.7797, Accuracy: 0.5000
# Batch no: 071, Loss on trainig: 1.9772, Accuracy: 0.5312
# Batch no: 072, Loss on trainig: 1.8803, Accuracy: 0.5000
# Batch no: 073, Loss on trainig: 1.8648, Accuracy: 0.5000
# Batch no: 074, Loss on trainig: 1.9232, Accuracy: 0.5000
# Batch no: 075, Loss on trainig: 2.0888, Accuracy: 0.4062
# Batch no: 076, Loss on trainig: 2.0036, Accuracy: 0.4844
# Batch no: 077, Loss on trainig: 1.9763, Accuracy: 0.4688
# Batch no: 078, Loss on trainig: 2.1988, Accuracy: 0.3750
# Batch no: 079, Loss on trainig: 1.7429, Accuracy: 0.5469
# Batch no: 080, Loss on trainig: 1.8618, Accuracy: 0.4688
# Batch no: 081, Loss on trainig: 1.8743, Accuracy: 0.5938
# Batch no: 082, Loss on trainig: 2.1234, Accuracy: 0.3906
# Batch no: 083, Loss on trainig: 2.1068, Accuracy: 0.4219
# Batch no: 084, Loss on trainig: 2.0516, Accuracy: 0.3906
# Batch no: 085, Loss on trainig: 2.1322, Accuracy: 0.4844
# Batch no: 086, Loss on trainig: 1.9719, Accuracy: 0.4531
# Batch no: 087, Loss on trainig: 1.7809, Accuracy: 0.5312
# Batch no: 088, Loss on trainig: 1.8693, Accuracy: 0.4688
# Batch no: 089, Loss on trainig: 1.6618, Accuracy: 0.5625
# Batch no: 090, Loss on trainig: 2.1128, Accuracy: 0.3438
# Batch no: 091, Loss on trainig: 1.8035, Accuracy: 0.5000
# Batch no: 092, Loss on trainig: 1.7461, Accuracy: 0.5156
# Batch no: 093, Loss on trainig: 1.6492, Accuracy: 0.4688
# Batch no: 094, Loss on trainig: 1.8135, Accuracy: 0.5781
# Batch no: 095, Loss on trainig: 1.5514, Accuracy: 0.5625
# Batch no: 096, Loss on trainig: 1.9032, Accuracy: 0.4844
# Batch no: 097, Loss on trainig: 1.6764, Accuracy: 0.4688
# Batch no: 098, Loss on trainig: 2.0922, Accuracy: 0.3594
# Batch no: 099, Loss on trainig: 1.9541, Accuracy: 0.4375
# Batch no: 100, Loss on trainig: 1.8919, Accuracy: 0.4844
# Batch no: 101, Loss on trainig: 1.8834, Accuracy: 0.4531
# Batch no: 102, Loss on trainig: 2.1499, Accuracy: 0.3333
# Epoch: 6/19
# Batch no: 000, Loss on trainig: 1.9493, Accuracy: 0.4219
# Batch no: 001, Loss on trainig: 1.7529, Accuracy: 0.6094
# Batch no: 002, Loss on trainig: 2.1041, Accuracy: 0.4844
# Batch no: 003, Loss on trainig: 1.6513, Accuracy: 0.6406
# Batch no: 004, Loss on trainig: 2.3149, Accuracy: 0.4375
# Batch no: 005, Loss on trainig: 2.1166, Accuracy: 0.3750
# Batch no: 006, Loss on trainig: 1.7417, Accuracy: 0.5156
# Batch no: 007, Loss on trainig: 2.1906, Accuracy: 0.4062
# Batch no: 008, Loss on trainig: 1.7727, Accuracy: 0.4688
# Batch no: 009, Loss on trainig: 1.8441, Accuracy: 0.5156
# Batch no: 010, Loss on trainig: 2.0850, Accuracy: 0.3906
# Batch no: 011, Loss on trainig: 2.1001, Accuracy: 0.3750
# Batch no: 012, Loss on trainig: 1.6084, Accuracy: 0.5781
# Batch no: 013, Loss on trainig: 1.6541, Accuracy: 0.4531
# Batch no: 014, Loss on trainig: 2.3975, Accuracy: 0.3906
# Batch no: 015, Loss on trainig: 1.2834, Accuracy: 0.6406
# Batch no: 016, Loss on trainig: 1.7238, Accuracy: 0.5156
# Batch no: 017, Loss on trainig: 1.3988, Accuracy: 0.5312
# Batch no: 018, Loss on trainig: 1.7401, Accuracy: 0.5312
# Batch no: 019, Loss on trainig: 1.6180, Accuracy: 0.5938
# Batch no: 020, Loss on trainig: 1.7285, Accuracy: 0.5625
# Batch no: 021, Loss on trainig: 1.6964, Accuracy: 0.5469
# Batch no: 022, Loss on trainig: 2.1386, Accuracy: 0.4062
# Batch no: 023, Loss on trainig: 1.4895, Accuracy: 0.5938
# Batch no: 024, Loss on trainig: 1.6104, Accuracy: 0.5312
# Batch no: 025, Loss on trainig: 2.0642, Accuracy: 0.4688
# Batch no: 026, Loss on trainig: 1.8498, Accuracy: 0.4219
# Batch no: 027, Loss on trainig: 1.6566, Accuracy: 0.4844
# Batch no: 028, Loss on trainig: 1.8444, Accuracy: 0.4844
# Batch no: 029, Loss on trainig: 1.6927, Accuracy: 0.5156
# Batch no: 030, Loss on trainig: 1.9755, Accuracy: 0.5000
# Batch no: 031, Loss on trainig: 1.9276, Accuracy: 0.4844
# Batch no: 032, Loss on trainig: 2.0704, Accuracy: 0.3906
# Batch no: 033, Loss on trainig: 2.2399, Accuracy: 0.4219
# Batch no: 034, Loss on trainig: 1.6993, Accuracy: 0.4531
# Batch no: 035, Loss on trainig: 2.0590, Accuracy: 0.4219
# Batch no: 036, Loss on trainig: 2.0597, Accuracy: 0.4688
# Batch no: 037, Loss on trainig: 1.9386, Accuracy: 0.4219
# Batch no: 038, Loss on trainig: 2.0159, Accuracy: 0.4219
# Batch no: 039, Loss on trainig: 1.7300, Accuracy: 0.5781
# Batch no: 040, Loss on trainig: 2.2253, Accuracy: 0.3906
# Batch no: 041, Loss on trainig: 2.0566, Accuracy: 0.4688
# Batch no: 042, Loss on trainig: 1.5533, Accuracy: 0.5156
# Batch no: 043, Loss on trainig: 1.7590, Accuracy: 0.5469
# Batch no: 044, Loss on trainig: 1.8600, Accuracy: 0.4844
# Batch no: 045, Loss on trainig: 1.7045, Accuracy: 0.5156
# Batch no: 046, Loss on trainig: 1.5162, Accuracy: 0.5625
# Batch no: 047, Loss on trainig: 1.8592, Accuracy: 0.4062
# Batch no: 048, Loss on trainig: 2.1412, Accuracy: 0.4062
# Batch no: 049, Loss on trainig: 1.9647, Accuracy: 0.4844
# Batch no: 050, Loss on trainig: 2.0263, Accuracy: 0.5156
# Batch no: 051, Loss on trainig: 1.5419, Accuracy: 0.5312
# Batch no: 052, Loss on trainig: 2.0883, Accuracy: 0.4688
# Batch no: 053, Loss on trainig: 1.7419, Accuracy: 0.5625
# Batch no: 054, Loss on trainig: 1.6314, Accuracy: 0.5000
# Batch no: 055, Loss on trainig: 1.8990, Accuracy: 0.5000
# Batch no: 056, Loss on trainig: 1.5596, Accuracy: 0.5625
# Batch no: 057, Loss on trainig: 1.8314, Accuracy: 0.4688
# Batch no: 058, Loss on trainig: 1.9791, Accuracy: 0.4375
# Batch no: 059, Loss on trainig: 1.9454, Accuracy: 0.4688
# Batch no: 060, Loss on trainig: 2.0601, Accuracy: 0.4531
# Batch no: 061, Loss on trainig: 1.3182, Accuracy: 0.6250
# Batch no: 062, Loss on trainig: 2.3156, Accuracy: 0.3281
# Batch no: 063, Loss on trainig: 1.7002, Accuracy: 0.4062
# Batch no: 064, Loss on trainig: 1.6052, Accuracy: 0.6094
# Batch no: 065, Loss on trainig: 1.9312, Accuracy: 0.4688
# Batch no: 066, Loss on trainig: 1.9350, Accuracy: 0.4844
# Batch no: 067, Loss on trainig: 1.5954, Accuracy: 0.5781
# Batch no: 068, Loss on trainig: 1.8441, Accuracy: 0.6094
# Batch no: 069, Loss on trainig: 1.7975, Accuracy: 0.4688
# Batch no: 070, Loss on trainig: 2.2040, Accuracy: 0.3594
# Batch no: 071, Loss on trainig: 1.4947, Accuracy: 0.5938
# Batch no: 072, Loss on trainig: 1.9251, Accuracy: 0.4531
# Batch no: 073, Loss on trainig: 1.9303, Accuracy: 0.5000
# Batch no: 074, Loss on trainig: 2.0682, Accuracy: 0.5469
# Batch no: 075, Loss on trainig: 1.4958, Accuracy: 0.5312
# Batch no: 076, Loss on trainig: 1.9122, Accuracy: 0.5156
# Batch no: 077, Loss on trainig: 2.0562, Accuracy: 0.3594
# Batch no: 078, Loss on trainig: 1.9252, Accuracy: 0.4375
# Batch no: 079, Loss on trainig: 1.7379, Accuracy: 0.5781
# Batch no: 080, Loss on trainig: 2.0483, Accuracy: 0.4375
# Batch no: 081, Loss on trainig: 1.7323, Accuracy: 0.5469
# Batch no: 082, Loss on trainig: 1.6613, Accuracy: 0.4844
# Batch no: 083, Loss on trainig: 1.9259, Accuracy: 0.4219
# Batch no: 084, Loss on trainig: 1.7885, Accuracy: 0.5312
# Batch no: 085, Loss on trainig: 2.2097, Accuracy: 0.4375
# Batch no: 086, Loss on trainig: 1.9412, Accuracy: 0.4531
# Batch no: 087, Loss on trainig: 1.9993, Accuracy: 0.4375
# Batch no: 088, Loss on trainig: 1.7775, Accuracy: 0.5000
# Batch no: 089, Loss on trainig: 1.5470, Accuracy: 0.5625
# Batch no: 090, Loss on trainig: 1.9321, Accuracy: 0.4844
# Batch no: 091, Loss on trainig: 2.0093, Accuracy: 0.4531
# Batch no: 092, Loss on trainig: 1.9651, Accuracy: 0.4375
# Batch no: 093, Loss on trainig: 1.4811, Accuracy: 0.5312
# Batch no: 094, Loss on trainig: 1.6183, Accuracy: 0.5156
# Batch no: 095, Loss on trainig: 1.4627, Accuracy: 0.6875
# Batch no: 096, Loss on trainig: 1.6374, Accuracy: 0.5312
# Batch no: 097, Loss on trainig: 1.4489, Accuracy: 0.5625
# Batch no: 098, Loss on trainig: 2.2756, Accuracy: 0.4219
# Batch no: 099, Loss on trainig: 1.4777, Accuracy: 0.6250
# Batch no: 100, Loss on trainig: 1.9385, Accuracy: 0.4844
# Batch no: 101, Loss on trainig: 1.5285, Accuracy: 0.5469
# Batch no: 102, Loss on trainig: 1.6412, Accuracy: 0.4583
# Epoch: 7/19
# Batch no: 000, Loss on trainig: 1.7333, Accuracy: 0.4844
# Batch no: 001, Loss on trainig: 1.6101, Accuracy: 0.5000
# Batch no: 002, Loss on trainig: 1.8668, Accuracy: 0.4844
# Batch no: 003, Loss on trainig: 1.8051, Accuracy: 0.4688
# Batch no: 004, Loss on trainig: 1.6680, Accuracy: 0.5000
# Batch no: 005, Loss on trainig: 1.6802, Accuracy: 0.5156
# Batch no: 006, Loss on trainig: 1.5600, Accuracy: 0.5625
# Batch no: 007, Loss on trainig: 1.7944, Accuracy: 0.4844
# Batch no: 008, Loss on trainig: 1.9535, Accuracy: 0.4219
# Batch no: 009, Loss on trainig: 1.9293, Accuracy: 0.5000
# Batch no: 010, Loss on trainig: 1.5976, Accuracy: 0.5312
# Batch no: 011, Loss on trainig: 1.6285, Accuracy: 0.5000
# Batch no: 012, Loss on trainig: 1.6013, Accuracy: 0.5000
# Batch no: 013, Loss on trainig: 1.7950, Accuracy: 0.5000
# Batch no: 014, Loss on trainig: 1.3330, Accuracy: 0.5938
# Batch no: 015, Loss on trainig: 1.7354, Accuracy: 0.5156
# Batch no: 016, Loss on trainig: 1.7709, Accuracy: 0.5469
# Batch no: 017, Loss on trainig: 1.8348, Accuracy: 0.4844
# Batch no: 018, Loss on trainig: 1.8428, Accuracy: 0.5312
# Batch no: 019, Loss on trainig: 1.4269, Accuracy: 0.5469
# Batch no: 020, Loss on trainig: 1.9687, Accuracy: 0.5000
# Batch no: 021, Loss on trainig: 1.8736, Accuracy: 0.5312
# Batch no: 022, Loss on trainig: 1.9944, Accuracy: 0.4219
# Batch no: 023, Loss on trainig: 1.5583, Accuracy: 0.5781
# Batch no: 024, Loss on trainig: 1.3455, Accuracy: 0.6562
# Batch no: 025, Loss on trainig: 2.2363, Accuracy: 0.4062
# Batch no: 026, Loss on trainig: 1.7830, Accuracy: 0.5938
# Batch no: 027, Loss on trainig: 1.5248, Accuracy: 0.5781
# Batch no: 028, Loss on trainig: 1.9183, Accuracy: 0.4531
# Batch no: 029, Loss on trainig: 1.8456, Accuracy: 0.5625
# Batch no: 030, Loss on trainig: 1.7957, Accuracy: 0.4375
# Batch no: 031, Loss on trainig: 1.2491, Accuracy: 0.6562
# Batch no: 032, Loss on trainig: 1.8512, Accuracy: 0.4531
# Batch no: 033, Loss on trainig: 1.3862, Accuracy: 0.6094
# Batch no: 034, Loss on trainig: 1.6886, Accuracy: 0.4688
# Batch no: 035, Loss on trainig: 1.8168, Accuracy: 0.4531
# Batch no: 036, Loss on trainig: 1.6963, Accuracy: 0.5469
# Batch no: 037, Loss on trainig: 1.8895, Accuracy: 0.5312
# Batch no: 038, Loss on trainig: 1.7827, Accuracy: 0.5469
# Batch no: 039, Loss on trainig: 1.6554, Accuracy: 0.5625
# Batch no: 040, Loss on trainig: 1.8443, Accuracy: 0.4844
# Batch no: 041, Loss on trainig: 1.5120, Accuracy: 0.6094
# Batch no: 042, Loss on trainig: 1.5901, Accuracy: 0.5156
# Batch no: 043, Loss on trainig: 1.7303, Accuracy: 0.4844
# Batch no: 044, Loss on trainig: 1.5978, Accuracy: 0.5781
# Batch no: 045, Loss on trainig: 1.8091, Accuracy: 0.4375
# Batch no: 046, Loss on trainig: 1.5993, Accuracy: 0.5781
# Batch no: 047, Loss on trainig: 1.7612, Accuracy: 0.5156
# Batch no: 048, Loss on trainig: 1.9531, Accuracy: 0.5312
# Batch no: 049, Loss on trainig: 1.3939, Accuracy: 0.6094
# Batch no: 050, Loss on trainig: 1.9834, Accuracy: 0.5000
# Batch no: 051, Loss on trainig: 2.0309, Accuracy: 0.4375
# Batch no: 052, Loss on trainig: 1.5541, Accuracy: 0.5625
# Batch no: 053, Loss on trainig: 1.4650, Accuracy: 0.6094
# Batch no: 054, Loss on trainig: 1.5662, Accuracy: 0.5625
# Batch no: 055, Loss on trainig: 1.9168, Accuracy: 0.5469
# Batch no: 056, Loss on trainig: 1.6875, Accuracy: 0.5469
# Batch no: 057, Loss on trainig: 1.9255, Accuracy: 0.4531
# Batch no: 058, Loss on trainig: 1.8319, Accuracy: 0.5000
# Batch no: 059, Loss on trainig: 1.4420, Accuracy: 0.5781
# Batch no: 060, Loss on trainig: 1.5969, Accuracy: 0.5312
# Batch no: 061, Loss on trainig: 1.9977, Accuracy: 0.5156
# Batch no: 062, Loss on trainig: 1.6964, Accuracy: 0.5312
# Batch no: 063, Loss on trainig: 1.9843, Accuracy: 0.4531
# Batch no: 064, Loss on trainig: 1.6259, Accuracy: 0.5625
# Batch no: 065, Loss on trainig: 1.8521, Accuracy: 0.4531
# Batch no: 066, Loss on trainig: 1.5984, Accuracy: 0.5469
# Batch no: 067, Loss on trainig: 1.9110, Accuracy: 0.5000
# Batch no: 068, Loss on trainig: 1.5804, Accuracy: 0.5781
# Batch no: 069, Loss on trainig: 1.5907, Accuracy: 0.4844
# Batch no: 070, Loss on trainig: 1.7293, Accuracy: 0.6094
# Batch no: 071, Loss on trainig: 1.4498, Accuracy: 0.5625
# Batch no: 072, Loss on trainig: 1.9086, Accuracy: 0.4844
# Batch no: 073, Loss on trainig: 1.7900, Accuracy: 0.4844
# Batch no: 074, Loss on trainig: 1.9682, Accuracy: 0.3906
# Batch no: 075, Loss on trainig: 1.8331, Accuracy: 0.5000
# Batch no: 076, Loss on trainig: 1.7535, Accuracy: 0.5156
# Batch no: 077, Loss on trainig: 1.7686, Accuracy: 0.5625
# Batch no: 078, Loss on trainig: 1.5845, Accuracy: 0.4844
# Batch no: 079, Loss on trainig: 1.6326, Accuracy: 0.5469
# Batch no: 080, Loss on trainig: 1.9584, Accuracy: 0.4531
# Batch no: 081, Loss on trainig: 1.6578, Accuracy: 0.5469
# Batch no: 082, Loss on trainig: 1.5515, Accuracy: 0.5938
# Batch no: 083, Loss on trainig: 1.9191, Accuracy: 0.5156
# Batch no: 084, Loss on trainig: 1.9378, Accuracy: 0.5469
# Batch no: 085, Loss on trainig: 1.7213, Accuracy: 0.5938
# Batch no: 086, Loss on trainig: 1.6210, Accuracy: 0.5469
# Batch no: 087, Loss on trainig: 1.5858, Accuracy: 0.5469
# Batch no: 088, Loss on trainig: 1.9645, Accuracy: 0.5312
# Batch no: 089, Loss on trainig: 1.3040, Accuracy: 0.6406
# Batch no: 090, Loss on trainig: 1.5274, Accuracy: 0.5781
# Batch no: 091, Loss on trainig: 1.6452, Accuracy: 0.6094
# Batch no: 092, Loss on trainig: 1.8409, Accuracy: 0.5000
# Batch no: 093, Loss on trainig: 2.0696, Accuracy: 0.4375
# Batch no: 094, Loss on trainig: 2.0957, Accuracy: 0.4531
# Batch no: 095, Loss on trainig: 1.6195, Accuracy: 0.5156
# Batch no: 096, Loss on trainig: 2.1041, Accuracy: 0.4375
# Batch no: 097, Loss on trainig: 1.4993, Accuracy: 0.5938
# Batch no: 098, Loss on trainig: 1.4712, Accuracy: 0.6250
# Batch no: 099, Loss on trainig: 1.8504, Accuracy: 0.4844
# Batch no: 100, Loss on trainig: 1.9411, Accuracy: 0.4531
# Batch no: 101, Loss on trainig: 1.8284, Accuracy: 0.5781
# Batch no: 102, Loss on trainig: 1.2853, Accuracy: 0.7083
# Epoch: 8/19
# Batch no: 000, Loss on trainig: 1.4147, Accuracy: 0.6094
# Batch no: 001, Loss on trainig: 1.6988, Accuracy: 0.5469
# Batch no: 002, Loss on trainig: 1.6910, Accuracy: 0.5312
# Batch no: 003, Loss on trainig: 1.8202, Accuracy: 0.5156
# Batch no: 004, Loss on trainig: 1.9454, Accuracy: 0.4375
# Batch no: 005, Loss on trainig: 1.8288, Accuracy: 0.5312
# Batch no: 006, Loss on trainig: 1.5675, Accuracy: 0.6250
# Batch no: 007, Loss on trainig: 1.4693, Accuracy: 0.6250
# Batch no: 008, Loss on trainig: 1.5347, Accuracy: 0.5625
# Batch no: 009, Loss on trainig: 1.4482, Accuracy: 0.6406
# Batch no: 010, Loss on trainig: 1.2683, Accuracy: 0.6094
# Batch no: 011, Loss on trainig: 1.8016, Accuracy: 0.5312
# Batch no: 012, Loss on trainig: 1.4011, Accuracy: 0.6875
# Batch no: 013, Loss on trainig: 1.6225, Accuracy: 0.5625
# Batch no: 014, Loss on trainig: 1.5284, Accuracy: 0.5938
# Batch no: 015, Loss on trainig: 1.4912, Accuracy: 0.6094
# Batch no: 016, Loss on trainig: 1.6922, Accuracy: 0.4688
# Batch no: 017, Loss on trainig: 1.7117, Accuracy: 0.5469
# Batch no: 018, Loss on trainig: 1.6495, Accuracy: 0.5156
# Batch no: 019, Loss on trainig: 1.5295, Accuracy: 0.6094
# Batch no: 020, Loss on trainig: 1.7626, Accuracy: 0.5312
# Batch no: 021, Loss on trainig: 1.5751, Accuracy: 0.6094
# Batch no: 022, Loss on trainig: 1.5307, Accuracy: 0.5625
# Batch no: 023, Loss on trainig: 1.3606, Accuracy: 0.6562
# Batch no: 024, Loss on trainig: 1.6213, Accuracy: 0.5781
# Batch no: 025, Loss on trainig: 1.5614, Accuracy: 0.5625
# Batch no: 026, Loss on trainig: 1.7511, Accuracy: 0.5156
# Batch no: 027, Loss on trainig: 1.6359, Accuracy: 0.5938
# Batch no: 028, Loss on trainig: 1.9141, Accuracy: 0.5000
# Batch no: 029, Loss on trainig: 1.5340, Accuracy: 0.5938
# Batch no: 030, Loss on trainig: 1.7175, Accuracy: 0.5312
# Batch no: 031, Loss on trainig: 2.0204, Accuracy: 0.5000
# Batch no: 032, Loss on trainig: 1.5351, Accuracy: 0.5625
# Batch no: 033, Loss on trainig: 1.6299, Accuracy: 0.5156
# Batch no: 034, Loss on trainig: 1.7974, Accuracy: 0.5469
# Batch no: 035, Loss on trainig: 1.7079, Accuracy: 0.5156
# Batch no: 036, Loss on trainig: 1.9723, Accuracy: 0.5000
# Batch no: 037, Loss on trainig: 1.8483, Accuracy: 0.4844
# Batch no: 038, Loss on trainig: 1.8621, Accuracy: 0.5000
# Batch no: 039, Loss on trainig: 1.8550, Accuracy: 0.5625
# Batch no: 040, Loss on trainig: 1.8243, Accuracy: 0.5000
# Batch no: 041, Loss on trainig: 1.8802, Accuracy: 0.4844
# Batch no: 042, Loss on trainig: 1.6715, Accuracy: 0.5469
# Batch no: 043, Loss on trainig: 1.2748, Accuracy: 0.6250
# Batch no: 044, Loss on trainig: 2.1295, Accuracy: 0.4531
# Batch no: 045, Loss on trainig: 2.0046, Accuracy: 0.4844
# Batch no: 046, Loss on trainig: 1.7394, Accuracy: 0.5469
# Batch no: 047, Loss on trainig: 1.6361, Accuracy: 0.5312
# Batch no: 048, Loss on trainig: 1.6054, Accuracy: 0.5312
# Batch no: 049, Loss on trainig: 1.9873, Accuracy: 0.4531
# Batch no: 050, Loss on trainig: 1.8926, Accuracy: 0.4375
# Batch no: 051, Loss on trainig: 2.0291, Accuracy: 0.4688
# Batch no: 052, Loss on trainig: 2.0079, Accuracy: 0.4531
# Batch no: 053, Loss on trainig: 1.6258, Accuracy: 0.5312
# Batch no: 054, Loss on trainig: 1.5443, Accuracy: 0.5938
# Batch no: 055, Loss on trainig: 1.4336, Accuracy: 0.5938
# Batch no: 056, Loss on trainig: 1.6482, Accuracy: 0.5625
# Batch no: 057, Loss on trainig: 2.1211, Accuracy: 0.4688
# Batch no: 058, Loss on trainig: 1.7526, Accuracy: 0.5156
# Batch no: 059, Loss on trainig: 1.9235, Accuracy: 0.4688
# Batch no: 060, Loss on trainig: 1.6976, Accuracy: 0.5469
# Batch no: 061, Loss on trainig: 1.5683, Accuracy: 0.6094
# Batch no: 062, Loss on trainig: 1.9150, Accuracy: 0.4844
# Batch no: 063, Loss on trainig: 1.4154, Accuracy: 0.6094
# Batch no: 064, Loss on trainig: 1.4298, Accuracy: 0.5000
# Batch no: 065, Loss on trainig: 1.7242, Accuracy: 0.5312
# Batch no: 066, Loss on trainig: 1.7785, Accuracy: 0.4844
# Batch no: 067, Loss on trainig: 1.8544, Accuracy: 0.4531
# Batch no: 068, Loss on trainig: 1.8386, Accuracy: 0.4844
# Batch no: 069, Loss on trainig: 1.3232, Accuracy: 0.6094
# Batch no: 070, Loss on trainig: 1.7623, Accuracy: 0.4375
# Batch no: 071, Loss on trainig: 1.5653, Accuracy: 0.4531
# Batch no: 072, Loss on trainig: 1.8359, Accuracy: 0.5469
# Batch no: 073, Loss on trainig: 1.7132, Accuracy: 0.4688
# Batch no: 074, Loss on trainig: 1.6558, Accuracy: 0.6094
# Batch no: 075, Loss on trainig: 1.9193, Accuracy: 0.4688
# Batch no: 076, Loss on trainig: 1.5313, Accuracy: 0.5781
# Batch no: 077, Loss on trainig: 1.8772, Accuracy: 0.4531
# Batch no: 078, Loss on trainig: 1.7306, Accuracy: 0.5312
# Batch no: 079, Loss on trainig: 1.5272, Accuracy: 0.5781
# Batch no: 080, Loss on trainig: 1.3740, Accuracy: 0.5938
# Batch no: 081, Loss on trainig: 1.3967, Accuracy: 0.6094
# Batch no: 082, Loss on trainig: 2.2270, Accuracy: 0.4375
# Batch no: 083, Loss on trainig: 1.8646, Accuracy: 0.4688
# Batch no: 084, Loss on trainig: 1.2580, Accuracy: 0.6406
# Batch no: 085, Loss on trainig: 1.4690, Accuracy: 0.5781
# Batch no: 086, Loss on trainig: 1.8193, Accuracy: 0.5000
# Batch no: 087, Loss on trainig: 1.5854, Accuracy: 0.5781
# Batch no: 088, Loss on trainig: 1.6954, Accuracy: 0.5625
# Batch no: 089, Loss on trainig: 2.3250, Accuracy: 0.4688
# Batch no: 090, Loss on trainig: 1.8501, Accuracy: 0.4844
# Batch no: 091, Loss on trainig: 1.6721, Accuracy: 0.5000
# Batch no: 092, Loss on trainig: 1.6738, Accuracy: 0.4531
# Batch no: 093, Loss on trainig: 1.7013, Accuracy: 0.5312
# Batch no: 094, Loss on trainig: 1.4624, Accuracy: 0.5938
# Batch no: 095, Loss on trainig: 1.9493, Accuracy: 0.5000
# Batch no: 096, Loss on trainig: 1.7440, Accuracy: 0.5625
# Batch no: 097, Loss on trainig: 1.6919, Accuracy: 0.5625
# Batch no: 098, Loss on trainig: 1.6084, Accuracy: 0.5625
# Batch no: 099, Loss on trainig: 1.7092, Accuracy: 0.5312
# Batch no: 100, Loss on trainig: 1.6303, Accuracy: 0.5781
# Batch no: 101, Loss on trainig: 1.8719, Accuracy: 0.4531
# Batch no: 102, Loss on trainig: 1.1610, Accuracy: 0.7083
# Epoch: 9/19
# Batch no: 000, Loss on trainig: 1.8600, Accuracy: 0.5000
# Batch no: 001, Loss on trainig: 1.3951, Accuracy: 0.6094
# Batch no: 002, Loss on trainig: 1.4729, Accuracy: 0.6094
# Batch no: 003, Loss on trainig: 1.6379, Accuracy: 0.5312
# Batch no: 004, Loss on trainig: 1.7754, Accuracy: 0.5000
# Batch no: 005, Loss on trainig: 1.5083, Accuracy: 0.6250
# Batch no: 006, Loss on trainig: 1.5210, Accuracy: 0.6094
# Batch no: 007, Loss on trainig: 1.4911, Accuracy: 0.5156
# Batch no: 008, Loss on trainig: 1.9642, Accuracy: 0.5781
# Batch no: 009, Loss on trainig: 1.7848, Accuracy: 0.4844
# Batch no: 010, Loss on trainig: 1.2645, Accuracy: 0.6562
# Batch no: 011, Loss on trainig: 1.6997, Accuracy: 0.6094
# Batch no: 012, Loss on trainig: 1.3123, Accuracy: 0.6250
# Batch no: 013, Loss on trainig: 1.6042, Accuracy: 0.5781
# Batch no: 014, Loss on trainig: 1.4899, Accuracy: 0.6406
# Batch no: 015, Loss on trainig: 2.0618, Accuracy: 0.4375
# ...
# Batch no: 029, Loss on trainig: 1.8403, Accuracy: 0.4844
# Batch no: 030, Loss on trainig: 1.2422, Accuracy: 0.5781
# Batch no: 031, Loss on trainig: 1.2020, Accuracy: 0.7188
# Batch no: 032, Loss on trainig: 1.3184, Accuracy: 0.6562
# Batch no: 033, Loss on trainig: 1.2743, Accuracy: 0.6875
# Batch no: 034, Loss on trainig: 1.0937, Accuracy: 0.7031
# Batch no: 035, Loss on trainig: 1.5637, Accuracy: 0.5781
# Batch no: 036, Loss on trainig: 1.5505, Accuracy: 0.6406
# Batch no: 037, Loss on trainig: 1.3365, Accuracy: 0.6406
# Batch no: 038, Loss on trainig: 1.1464, Accuracy: 0.6562
# Batch no: 039, Loss on trainig: 1.5881, Accuracy: 0.5469
# Batch no: 040, Loss on trainig: 1.1993, Accuracy: 0.6250
# Batch no: 041, Loss on trainig: 1.2086, Accuracy: 0.6250
# Batch no: 042, Loss on trainig: 1.6040, Accuracy: 0.5938
# Batch no: 043, Loss on trainig: 1.3582, Accuracy: 0.6406
# Batch no: 044, Loss on trainig: 1.3292, Accuracy: 0.6250
# Batch no: 045, Loss on trainig: 1.2800, Accuracy: 0.6875
# Batch no: 046, Loss on trainig: 1.2005, Accuracy: 0.6562
# Batch no: 047, Loss on trainig: 1.3040, Accuracy: 0.6250
# Batch no: 048, Loss on trainig: 1.4089, Accuracy: 0.5156
# Batch no: 049, Loss on trainig: 1.0329, Accuracy: 0.6875
# Batch no: 050, Loss on trainig: 1.2368, Accuracy: 0.6719
# Batch no: 051, Loss on trainig: 1.3494, Accuracy: 0.6406
# Batch no: 052, Loss on trainig: 1.8531, Accuracy: 0.5312
# Batch no: 053, Loss on trainig: 1.1078, Accuracy: 0.6875
# Batch no: 054, Loss on trainig: 1.7249, Accuracy: 0.4375
# Batch no: 055, Loss on trainig: 1.3750, Accuracy: 0.5938
# Batch no: 056, Loss on trainig: 1.2162, Accuracy: 0.7031
# Batch no: 057, Loss on trainig: 1.3128, Accuracy: 0.5625
# Batch no: 058, Loss on trainig: 1.0546, Accuracy: 0.7031
# Batch no: 059, Loss on trainig: 1.2154, Accuracy: 0.6406
# Batch no: 060, Loss on trainig: 1.4970, Accuracy: 0.5312
# Batch no: 061, Loss on trainig: 1.4383, Accuracy: 0.5938
# Batch no: 062, Loss on trainig: 1.7626, Accuracy: 0.5625
# Batch no: 063, Loss on trainig: 1.0136, Accuracy: 0.6719
# Batch no: 064, Loss on trainig: 0.9360, Accuracy: 0.7656
# Batch no: 065, Loss on trainig: 0.9706, Accuracy: 0.7500
# Batch no: 066, Loss on trainig: 1.2414, Accuracy: 0.7188
# Batch no: 067, Loss on trainig: 1.4587, Accuracy: 0.6250
# Batch no: 068, Loss on trainig: 1.6398, Accuracy: 0.4844
# Batch no: 069, Loss on trainig: 1.5192, Accuracy: 0.5625
# Batch no: 070, Loss on trainig: 1.5913, Accuracy: 0.5781
# Batch no: 071, Loss on trainig: 1.1151, Accuracy: 0.7031
# Batch no: 072, Loss on trainig: 1.0773, Accuracy: 0.7031
# Batch no: 073, Loss on trainig: 1.5764, Accuracy: 0.5156
# Batch no: 074, Loss on trainig: 1.6327, Accuracy: 0.6094
# Batch no: 075, Loss on trainig: 1.5867, Accuracy: 0.5625
# Batch no: 076, Loss on trainig: 1.7717, Accuracy: 0.5312
# Batch no: 077, Loss on trainig: 1.4708, Accuracy: 0.6562
# Batch no: 078, Loss on trainig: 1.1791, Accuracy: 0.6719
# Batch no: 079, Loss on trainig: 1.3123, Accuracy: 0.6719
# Batch no: 080, Loss on trainig: 1.4756, Accuracy: 0.5938
# Batch no: 081, Loss on trainig: 1.7233, Accuracy: 0.5156
# Batch no: 082, Loss on trainig: 1.4124, Accuracy: 0.5469
# Batch no: 083, Loss on trainig: 1.4529, Accuracy: 0.5625
# Batch no: 084, Loss on trainig: 1.6785, Accuracy: 0.6094
# Batch no: 085, Loss on trainig: 1.6340, Accuracy: 0.5938
# Batch no: 086, Loss on trainig: 1.3420, Accuracy: 0.6719
# Batch no: 087, Loss on trainig: 1.3453, Accuracy: 0.5781
# Batch no: 088, Loss on trainig: 1.0861, Accuracy: 0.7500
# Batch no: 089, Loss on trainig: 1.3074, Accuracy: 0.7031
# Batch no: 090, Loss on trainig: 1.2452, Accuracy: 0.6562
# Batch no: 091, Loss on trainig: 1.4652, Accuracy: 0.6406
# Batch no: 092, Loss on trainig: 1.0455, Accuracy: 0.7031
# Batch no: 093, Loss on trainig: 1.4899, Accuracy: 0.6719
# Batch no: 094, Loss on trainig: 1.2742, Accuracy: 0.6406
# Batch no: 095, Loss on trainig: 1.3265, Accuracy: 0.6562
# Batch no: 096, Loss on trainig: 1.3963, Accuracy: 0.5625
# Batch no: 097, Loss on trainig: 1.7921, Accuracy: 0.5312
# Batch no: 098, Loss on trainig: 1.4912, Accuracy: 0.5781
# Batch no: 099, Loss on trainig: 1.2398, Accuracy: 0.6562
# Batch no: 100, Loss on trainig: 1.6033, Accuracy: 0.5938
# Batch no: 101, Loss on trainig: 1.3140, Accuracy: 0.5469
# Batch no: 102, Loss on trainig: 2.1496, Accuracy: 0.5000
# Epoch: 18/19
# Batch no: 000, Loss on trainig: 0.8214, Accuracy: 0.7344
# Batch no: 001, Loss on trainig: 1.4654, Accuracy: 0.5625
# Batch no: 002, Loss on trainig: 1.1589, Accuracy: 0.6875
# Batch no: 003, Loss on trainig: 1.8163, Accuracy: 0.5000
# Batch no: 004, Loss on trainig: 1.3110, Accuracy: 0.5938
# Batch no: 005, Loss on trainig: 1.2123, Accuracy: 0.6875
# Batch no: 006, Loss on trainig: 0.9163, Accuracy: 0.7656
# Batch no: 007, Loss on trainig: 1.2419, Accuracy: 0.6250
# Batch no: 008, Loss on trainig: 1.3080, Accuracy: 0.6562
# Batch no: 009, Loss on trainig: 1.0873, Accuracy: 0.7500
# Batch no: 010, Loss on trainig: 1.2306, Accuracy: 0.6562
# Batch no: 011, Loss on trainig: 1.0499, Accuracy: 0.7344
# Batch no: 012, Loss on trainig: 1.1918, Accuracy: 0.6250
# Batch no: 013, Loss on trainig: 1.3586, Accuracy: 0.6094
# Batch no: 014, Loss on trainig: 1.4939, Accuracy: 0.6250
# Batch no: 015, Loss on trainig: 1.3778, Accuracy: 0.6875
# Batch no: 016, Loss on trainig: 1.1587, Accuracy: 0.7188
# Batch no: 017, Loss on trainig: 1.6337, Accuracy: 0.5312
# Batch no: 018, Loss on trainig: 1.4667, Accuracy: 0.5469
# Batch no: 019, Loss on trainig: 1.5573, Accuracy: 0.6094
# Batch no: 020, Loss on trainig: 1.6709, Accuracy: 0.6250
# Batch no: 021, Loss on trainig: 1.0621, Accuracy: 0.7031
# Batch no: 022, Loss on trainig: 1.2439, Accuracy: 0.6719
# Batch no: 023, Loss on trainig: 1.2036, Accuracy: 0.6094
# Batch no: 024, Loss on trainig: 1.3801, Accuracy: 0.6406
# Batch no: 025, Loss on trainig: 1.3789, Accuracy: 0.6250
# Batch no: 026, Loss on trainig: 1.1608, Accuracy: 0.6719
# Batch no: 027, Loss on trainig: 1.1632, Accuracy: 0.6094
# Batch no: 028, Loss on trainig: 1.8500, Accuracy: 0.5312
# Batch no: 029, Loss on trainig: 1.1277, Accuracy: 0.6719
# Batch no: 030, Loss on trainig: 1.6474, Accuracy: 0.6406
# Batch no: 031, Loss on trainig: 1.3408, Accuracy: 0.6094
# Batch no: 032, Loss on trainig: 1.4396, Accuracy: 0.6094
# Batch no: 033, Loss on trainig: 1.2396, Accuracy: 0.6406
# Batch no: 034, Loss on trainig: 1.2805, Accuracy: 0.6562
# Batch no: 035, Loss on trainig: 1.2971, Accuracy: 0.6719
# Batch no: 036, Loss on trainig: 1.0745, Accuracy: 0.7344
# Batch no: 037, Loss on trainig: 1.1474, Accuracy: 0.7031
# Batch no: 038, Loss on trainig: 1.2139, Accuracy: 0.6250
# Batch no: 039, Loss on trainig: 0.9770, Accuracy: 0.6562
# Batch no: 040, Loss on trainig: 1.4357, Accuracy: 0.5781
# Batch no: 041, Loss on trainig: 1.1373, Accuracy: 0.6250
# Batch no: 042, Loss on trainig: 1.2294, Accuracy: 0.6562
# Batch no: 043, Loss on trainig: 1.2356, Accuracy: 0.6250
# Batch no: 044, Loss on trainig: 1.1470, Accuracy: 0.6406
# Batch no: 045, Loss on trainig: 1.7448, Accuracy: 0.4531
# Batch no: 046, Loss on trainig: 1.3688, Accuracy: 0.5938
# Batch no: 047, Loss on trainig: 1.0987, Accuracy: 0.6719
# Batch no: 048, Loss on trainig: 1.4822, Accuracy: 0.6094
# Batch no: 049, Loss on trainig: 1.3142, Accuracy: 0.5938
# Batch no: 050, Loss on trainig: 1.2961, Accuracy: 0.6094
# Batch no: 051, Loss on trainig: 1.2614, Accuracy: 0.7031
# Batch no: 052, Loss on trainig: 1.2479, Accuracy: 0.6406
# Batch no: 053, Loss on trainig: 1.2277, Accuracy: 0.5781
# Batch no: 054, Loss on trainig: 1.0468, Accuracy: 0.6562
# Batch no: 055, Loss on trainig: 1.2487, Accuracy: 0.6250
# Batch no: 056, Loss on trainig: 1.5658, Accuracy: 0.5312
# Batch no: 057, Loss on trainig: 1.0212, Accuracy: 0.7031
# Batch no: 058, Loss on trainig: 1.2975, Accuracy: 0.6250
# Batch no: 059, Loss on trainig: 1.6126, Accuracy: 0.5000
# Batch no: 060, Loss on trainig: 1.1352, Accuracy: 0.6406
# Batch no: 061, Loss on trainig: 1.5115, Accuracy: 0.6094
# Batch no: 062, Loss on trainig: 1.2610, Accuracy: 0.6094
# Batch no: 063, Loss on trainig: 1.3092, Accuracy: 0.6094
# Batch no: 064, Loss on trainig: 1.2652, Accuracy: 0.6406
# Batch no: 065, Loss on trainig: 1.2732, Accuracy: 0.6719
# Batch no: 066, Loss on trainig: 1.2258, Accuracy: 0.6875
# Batch no: 067, Loss on trainig: 1.4743, Accuracy: 0.5938
# Batch no: 068, Loss on trainig: 0.8887, Accuracy: 0.7188
# Batch no: 069, Loss on trainig: 1.0561, Accuracy: 0.7344
# Batch no: 070, Loss on trainig: 1.6376, Accuracy: 0.5469
# Batch no: 071, Loss on trainig: 1.0314, Accuracy: 0.7500
# Batch no: 072, Loss on trainig: 1.5279, Accuracy: 0.5469
# Batch no: 073, Loss on trainig: 1.2166, Accuracy: 0.6406
# Batch no: 074, Loss on trainig: 1.4061, Accuracy: 0.6719
# Batch no: 075, Loss on trainig: 1.5561, Accuracy: 0.6094
# Batch no: 076, Loss on trainig: 1.7586, Accuracy: 0.5000
# Batch no: 077, Loss on trainig: 1.1569, Accuracy: 0.6719
# Batch no: 078, Loss on trainig: 1.6085, Accuracy: 0.5781
# Batch no: 079, Loss on trainig: 1.7347, Accuracy: 0.4688
# Batch no: 080, Loss on trainig: 1.1502, Accuracy: 0.6875
# Batch no: 081, Loss on trainig: 1.5237, Accuracy: 0.5781
# Batch no: 082, Loss on trainig: 1.3468, Accuracy: 0.6250
# Batch no: 083, Loss on trainig: 1.2658, Accuracy: 0.5938
# Batch no: 084, Loss on trainig: 0.8625, Accuracy: 0.6875
# Batch no: 085, Loss on trainig: 1.1408, Accuracy: 0.5938
# Batch no: 086, Loss on trainig: 1.5741, Accuracy: 0.5469
# Batch no: 087, Loss on trainig: 1.2964, Accuracy: 0.6562
# Batch no: 088, Loss on trainig: 1.3862, Accuracy: 0.6250
# Batch no: 089, Loss on trainig: 1.3817, Accuracy: 0.5781
# Batch no: 090, Loss on trainig: 0.8650, Accuracy: 0.7656
# Batch no: 091, Loss on trainig: 1.4052, Accuracy: 0.5625
# Batch no: 092, Loss on trainig: 1.5890, Accuracy: 0.5469
# Batch no: 093, Loss on trainig: 1.1946, Accuracy: 0.6719
# Batch no: 094, Loss on trainig: 1.8177, Accuracy: 0.5312
# Batch no: 095, Loss on trainig: 1.3053, Accuracy: 0.5938
# Batch no: 096, Loss on trainig: 1.6534, Accuracy: 0.5938
# Batch no: 097, Loss on trainig: 1.2825, Accuracy: 0.6719
# Batch no: 098, Loss on trainig: 1.3649, Accuracy: 0.6250
# Batch no: 099, Loss on trainig: 1.6029, Accuracy: 0.5781
# Batch no: 100, Loss on trainig: 1.2563, Accuracy: 0.6719
# Batch no: 101, Loss on trainig: 1.1302, Accuracy: 0.6875
# Batch no: 102, Loss on trainig: 1.7240, Accuracy: 0.5417
# Epoch: 19/19
# Batch no: 000, Loss on trainig: 1.0261, Accuracy: 0.6562
# Batch no: 001, Loss on trainig: 1.0085, Accuracy: 0.7031
# Batch no: 002, Loss on trainig: 1.2621, Accuracy: 0.6406
# Batch no: 003, Loss on trainig: 1.4466, Accuracy: 0.6094
# Batch no: 004, Loss on trainig: 1.2526, Accuracy: 0.6719
# Batch no: 005, Loss on trainig: 1.3785, Accuracy: 0.5781
# Batch no: 006, Loss on trainig: 1.3015, Accuracy: 0.5938
# Batch no: 007, Loss on trainig: 1.7587, Accuracy: 0.5312
# Batch no: 008, Loss on trainig: 1.0291, Accuracy: 0.6719
# Batch no: 009, Loss on trainig: 1.2211, Accuracy: 0.6562
# Batch no: 010, Loss on trainig: 1.3845, Accuracy: 0.6094
# Batch no: 011, Loss on trainig: 1.1616, Accuracy: 0.6875
# Batch no: 012, Loss on trainig: 1.2769, Accuracy: 0.6562
# Batch no: 013, Loss on trainig: 1.4430, Accuracy: 0.5781
# Batch no: 014, Loss on trainig: 1.2322, Accuracy: 0.6562
# Batch no: 015, Loss on trainig: 1.1655, Accuracy: 0.6719
# Batch no: 016, Loss on trainig: 1.1278, Accuracy: 0.6875
# Batch no: 017, Loss on trainig: 1.4851, Accuracy: 0.6250
# Batch no: 018, Loss on trainig: 1.3914, Accuracy: 0.6250
# Batch no: 019, Loss on trainig: 1.2927, Accuracy: 0.6094
# Batch no: 020, Loss on trainig: 1.4871, Accuracy: 0.5938
# Batch no: 021, Loss on trainig: 1.0823, Accuracy: 0.6875
# Batch no: 022, Loss on trainig: 1.0946, Accuracy: 0.6562
# Batch no: 023, Loss on trainig: 1.3143, Accuracy: 0.6406
# Batch no: 024, Loss on trainig: 1.5648, Accuracy: 0.6094
# Batch no: 025, Loss on trainig: 1.4018, Accuracy: 0.6094
# Batch no: 026, Loss on trainig: 1.1396, Accuracy: 0.6250
# Batch no: 027, Loss on trainig: 1.1638, Accuracy: 0.7188
# Batch no: 028, Loss on trainig: 1.3685, Accuracy: 0.5781
# Batch no: 029, Loss on trainig: 1.1716, Accuracy: 0.7031
# Batch no: 030, Loss on trainig: 1.2148, Accuracy: 0.6562
# Batch no: 031, Loss on trainig: 0.9854, Accuracy: 0.7031
# Batch no: 032, Loss on trainig: 0.9582, Accuracy: 0.7344
# Batch no: 033, Loss on trainig: 1.3194, Accuracy: 0.6562
# Batch no: 034, Loss on trainig: 1.2109, Accuracy: 0.5938
# Batch no: 035, Loss on trainig: 1.3818, Accuracy: 0.5469
# Batch no: 036, Loss on trainig: 1.0170, Accuracy: 0.7188
# Batch no: 037, Loss on trainig: 1.7363, Accuracy: 0.5625
# Batch no: 038, Loss on trainig: 1.1168, Accuracy: 0.6562
# Batch no: 039, Loss on trainig: 1.2831, Accuracy: 0.6562
# Batch no: 040, Loss on trainig: 1.0174, Accuracy: 0.7656
# Batch no: 041, Loss on trainig: 1.3742, Accuracy: 0.6719
# Batch no: 042, Loss on trainig: 1.0537, Accuracy: 0.7031
# Batch no: 043, Loss on trainig: 1.5049, Accuracy: 0.6094
# Batch no: 044, Loss on trainig: 1.1859, Accuracy: 0.5938
# Batch no: 045, Loss on trainig: 1.6846, Accuracy: 0.5156
# Batch no: 046, Loss on trainig: 1.3224, Accuracy: 0.6250
# Batch no: 047, Loss on trainig: 1.3428, Accuracy: 0.6094
# Batch no: 048, Loss on trainig: 1.4772, Accuracy: 0.6250
# Batch no: 049, Loss on trainig: 1.2778, Accuracy: 0.6094
# Batch no: 050, Loss on trainig: 1.4926, Accuracy: 0.5938
# Batch no: 051, Loss on trainig: 1.4630, Accuracy: 0.6094
# Batch no: 052, Loss on trainig: 1.2063, Accuracy: 0.5938
# Batch no: 053, Loss on trainig: 1.4497, Accuracy: 0.5156
# Batch no: 054, Loss on trainig: 1.1994, Accuracy: 0.6250
# Batch no: 055, Loss on trainig: 0.9741, Accuracy: 0.6875
# Batch no: 056, Loss on trainig: 1.3416, Accuracy: 0.6250
# Batch no: 057, Loss on trainig: 1.2092, Accuracy: 0.6406
# Batch no: 058, Loss on trainig: 1.4204, Accuracy: 0.5625
# Batch no: 059, Loss on trainig: 1.2315, Accuracy: 0.6875
# Batch no: 060, Loss on trainig: 1.2376, Accuracy: 0.6406
# Batch no: 061, Loss on trainig: 1.1788, Accuracy: 0.6250
# Batch no: 062, Loss on trainig: 1.0452, Accuracy: 0.7188
# Batch no: 063, Loss on trainig: 1.5808, Accuracy: 0.6094
# Batch no: 064, Loss on trainig: 1.3753, Accuracy: 0.6094
# Batch no: 065, Loss on trainig: 1.3858, Accuracy: 0.6250
# Batch no: 066, Loss on trainig: 1.6188, Accuracy: 0.5781
# Batch no: 067, Loss on trainig: 1.2999, Accuracy: 0.6250
# Batch no: 068, Loss on trainig: 1.2705, Accuracy: 0.5469
# Batch no: 069, Loss on trainig: 1.6572, Accuracy: 0.6094
# Batch no: 070, Loss on trainig: 1.0305, Accuracy: 0.6562
# Batch no: 071, Loss on trainig: 1.4090, Accuracy: 0.6406
# Batch no: 072, Loss on trainig: 1.4031, Accuracy: 0.6094
# Batch no: 073, Loss on trainig: 1.6963, Accuracy: 0.5000
# Batch no: 074, Loss on trainig: 1.5312, Accuracy: 0.5625
# Batch no: 075, Loss on trainig: 1.3820, Accuracy: 0.6406
# Batch no: 076, Loss on trainig: 1.0636, Accuracy: 0.7031
# Batch no: 077, Loss on trainig: 1.0719, Accuracy: 0.7344
# Batch no: 078, Loss on trainig: 1.3089, Accuracy: 0.6875
# Batch no: 079, Loss on trainig: 1.5924, Accuracy: 0.5938
# Batch no: 080, Loss on trainig: 1.4281, Accuracy: 0.6250
# Batch no: 081, Loss on trainig: 1.1554, Accuracy: 0.6719
# Batch no: 082, Loss on trainig: 1.2988, Accuracy: 0.6562
# Batch no: 083, Loss on trainig: 1.1907, Accuracy: 0.6562
# Batch no: 084, Loss on trainig: 1.2474, Accuracy: 0.6406
# Batch no: 085, Loss on trainig: 1.5570, Accuracy: 0.5625
# Batch no: 086, Loss on trainig: 0.9829, Accuracy: 0.7188
# Batch no: 087, Loss on trainig: 1.2374, Accuracy: 0.6406
# Batch no: 088, Loss on trainig: 1.1900, Accuracy: 0.6562
# Batch no: 089, Loss on trainig: 1.2209, Accuracy: 0.6094
# Batch no: 090, Loss on trainig: 1.1082, Accuracy: 0.6719
# Batch no: 091, Loss on trainig: 1.4053, Accuracy: 0.6562
# Batch no: 092, Loss on trainig: 1.1645, Accuracy: 0.6250
# Batch no: 093, Loss on trainig: 1.2592, Accuracy: 0.5781
# Batch no: 094, Loss on trainig: 1.2467, Accuracy: 0.5781
# Batch no: 095, Loss on trainig: 1.3130, Accuracy: 0.6094
# Batch no: 096, Loss on trainig: 1.8236, Accuracy: 0.5312
# Batch no: 097, Loss on trainig: 1.3570, Accuracy: 0.5781
# Batch no: 098, Loss on trainig: 1.0975, Accuracy: 0.6719
# Batch no: 099, Loss on trainig: 1.1820, Accuracy: 0.6875
# Batch no: 100, Loss on trainig: 1.6026, Accuracy: 0.6094
# Batch no: 101, Loss on trainig: 1.2260, Accuracy: 0.6562
# Batch no: 102, Loss on trainig: 1.2816, Accuracy: 0.6250

# %%
# TODO: Do validation on the test set

# Validation - No gradient tracking needed
with torch.no_grad():
    # Set to evaluation mode
    model.eval()


    # Validation loop
    for j, (inputs, labels) in enumerate(validation_loader):
        inputs = inputs.to('cuda')
        labels = labels.to('cuda')
 
        # Forward pass - compute outputs on input data using the model
        outputs = model(inputs)
 
        # Compute loss
        loss = criterion(outputs, labels)
 
        # Compute the total loss for the batch and add it to valid_loss
        valid_loss += loss.item() * inputs.size(0)
 
        # Calculate validation accuracy
        ret, predictions = torch.max(outputs.data, 1)
        correct_counts = predictions.eq(labels.data.view_as(predictions))
 
        # Convert correct_counts to float and then compute the mean
        acc = torch.mean(correct_counts.type(torch.FloatTensor))
 
        # Compute total accuracy in the whole batch and add to valid_acc
        valid_acc += acc.item() * inputs.size(0)
 
        print("Validation Batch number: {:03d}, Validation: Loss: {:.4f}, Accuracy: {:.4f}".format(j, loss.item(), acc.item()))
# Out:
# Validation Batch number: 000, Validation: Loss: 0.3849, Accuracy: 0.9375
# Validation Batch number: 001, Validation: Loss: 0.7014, Accuracy: 0.7969
# Validation Batch number: 002, Validation: Loss: 0.4784, Accuracy: 0.8438
# Validation Batch number: 003, Validation: Loss: 0.6510, Accuracy: 0.7969
# Validation Batch number: 004, Validation: Loss: 0.9025, Accuracy: 0.8281
# Validation Batch number: 005, Validation: Loss: 0.7218, Accuracy: 0.7969
# Validation Batch number: 006, Validation: Loss: 0.6481, Accuracy: 0.7812
# Validation Batch number: 007, Validation: Loss: 0.5042, Accuracy: 0.8906
# Validation Batch number: 008, Validation: Loss: 0.4524, Accuracy: 0.8750
# Validation Batch number: 009, Validation: Loss: 0.4844, Accuracy: 0.8438
# Validation Batch number: 010, Validation: Loss: 0.6491, Accuracy: 0.8281
# Validation Batch number: 011, Validation: Loss: 0.6082, Accuracy: 0.8438
# Validation Batch number: 012, Validation: Loss: 0.5326, Accuracy: 0.8400

# %% [markdown]
# ## Testing your network
#
# It's good practice to test your trained network on test data, images the network has never seen either in training or validation. This will give you a good estimate for the model's performance on completely new images. Run the test images through the network and measure the accuracy, the same way you did validation. You should be able to reach around 70% accuracy on the test set if the model has been trained well.

# %%
# Do validation on the test set
correct,total = 0,0
with torch.no_grad():
    model.eval()
    for data in train_loader:
        images, labels = data
        images, labels = images.to('cuda'), labels.to('cuda')
        outputs = model(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

print('Accuracy on test images is: %d%%' % (100 * correct / total))
# Out:
# Accuracy on test images is: 81%

# %%
print(model)
print(model.state_dict().keys())
# Out:
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (inputs): Linear(in_features=25088, out_features=120, bias=True)
#     (relu1): ReLU()
#     (dropout): Dropout(p=0.5)
#     (hidden_layer1): Linear(in_features=120, out_features=90, bias=True)
#     (relu2): ReLU()
#     (hidden_layer2): Linear(in_features=90, out_features=70, bias=True)
#     (relu3): ReLU()
#     (hidden_layer3): Linear(in_features=70, out_features=102, bias=True)
#     (output): LogSoftmax()
#   )
# )
# odict_keys(['features.0.weight', 'features.0.bias', 'features.2.weight', 'features.2.bias', 'features.5.weight', 'features.5.bias', 'features.7.weight', 'features.7.bias', 'features.10.weight', 'features.10.bias', 'features.12.weight', 'features.12.bias', 'features.14.weight', 'features.14.bias', 'features.17.weight', 'features.17.bias', 'features.19.weight', 'features.19.bias', 'features.21.weight', 'features.21.bias', 'features.24.weight', 'features.24.bias', 'features.26.weight', 'features.26.bias', 'features.28.weight', 'features.28.bias', 'classifier.inputs.weight', 'classifier.inputs.bias', 'classifier.hidden_layer1.weight', 'classifier.hidden_layer1.bias', 'classifier.hidden_layer2.weight', 'classifier.hidden_layer2.bias', 'classifier.hidden_layer3.weight', 'classifier.hidden_layer3.bias'])

# %% [markdown]
# ## Save the checkpoint
#
# Now that your network is trained, save the model so you can load it later for making predictions. You probably want to save other things such as the mapping of classes to indices which you get from one of the image datasets: `image_datasets['train'].class_to_idx`. You can attach this to the model as an attribute which makes inference easier later on.
#
# ```model.class_to_idx = image_datasets['train'].class_to_idx```
#
# Remember that you'll want to completely rebuild the model later so you can use it for inference. Make sure to include any information you need in the checkpoint. If you want to load the model and keep training, you'll want to save the number of epochs as well as the optimizer state, `optimizer.state_dict`. You'll likely want to use this trained model in the next part of the project, so best to save it now.

# %%
# TODO: Save the checkpoint 
model.class_to_idx = image_datasets['train'].class_to_idx
torch.save({'structure' :'alexnet',
            'hidden_layer1':120,
             'dropout':0.5,
             'epochs':19,
             'state_dict':model.state_dict(),
             'class_to_idx':model.class_to_idx,
             'optimizer_dict':optimizer.state_dict()},
             'checkpoint.pth')

# %% [markdown]
# ## Loading the checkpoint
#
# At this point it's good to write a function that can load a checkpoint and rebuild the model. That way you can come back to this project and keep working on it without having to retrain the network.

# %%
# TODO: Write a function that loads a checkpoint and rebuilds the model

# Using torch.load: Uses pickle’s unpickling facilities to deserialize pickled object files to memory.  
#with the format, torch.load(.., map_location='cpu')
def loading_the_checkpoint(path='checkpoint.pth'):
    #load the saved file
    checkpoint = torch.load('checkpoint.pth')
    #download pretrained model
    model=models.vgg16(pretrained=True)
    #to freeze parameters
    for param in model.parameters():
        param.requires_grad = False
    #load from checkpoint
    model.class_to_idx = checkpoint['class_to_idx']
    model.load_state_dict(checkpoint['state_dict'])
    return model

# %% [markdown]
# # Inference for classification
#
# Now you'll write a function to use a trained network for inference. That is, you'll pass an image into the network and predict the class of the flower in the image. Write a function called `predict` that takes an image and a model, then returns the top $K$ most likely classes along with the probabilities. It should look like
#
# ```python
# probs, classes = predict(image_path, model)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```
#
# First you'll need to handle processing the input image such that it can be used in your network.
#
# ## Image Preprocessing
#
# You'll want to use `PIL` to load the image ([documentation](https://pillow.readthedocs.io/en/latest/reference/Image.html)). It's best to write a function that preprocesses the image so it can be used as input for the model. This function should process the images in the same manner used for training.
#
# First, resize the images where the shortest side is 256 pixels, keeping the aspect ratio. This can be done with the [`thumbnail`](http://pillow.readthedocs.io/en/3.1.x/reference/Image.html#PIL.Image.Image.thumbnail) or [`resize`](http://pillow.readthedocs.io/en/3.1.x/reference/Image.html#PIL.Image.Image.thumbnail) methods. Then you'll need to crop out the center 224x224 portion of the image.
#
# Color channels of images are typically encoded as integers 0-255, but the model expected floats 0-1. You'll need to convert the values. It's easiest with a Numpy array, which you can get from a PIL image like so `np_image = np.array(pil_image)`.
#
# As before, the network expects the images to be normalized in a specific way. For the means, it's `[0.485, 0.456, 0.406]` and for the standard deviations `[0.229, 0.224, 0.225]`. You'll want to subtract the means from each color channel, then divide by the standard deviation.
#
# And finally, PyTorch expects the color channel to be the first dimension but it's the third dimension in the PIL image and Numpy array. You can reorder dimensions using [`ndarray.transpose`](https://docs.scipy.org/doc/numpy-1.13.0/reference/generated/numpy.ndarray.transpose.html). The color channel needs to be first and retain the order of the other two dimensions.

# %%
def process_image(image):
    ''' Scales, crops, and normalizes a PIL image for a PyTorch model,
        returns an Numpy array
    '''
    
    # TODO: Process a PIL image for use in a PyTorch model

    img = PIL.Image.open(image)

    # Get original dimensions
    original_width, original_height = img.size

    # Find shorter size and create settings to crop shortest side to 256
    if original_width < original_height:
        size=[256, 256**600]
    else: 
        size=[256**600, 256]
        
    img.thumbnail(size)
   

    center = original_width/4, original_height/4
    left, top, right, bottom = center[0]-(244/2), center[1]-(244/2), center[0]+(244/2), center[1]+(244/2)
    img = img.crop((left, top, right, bottom))

    numpy_img = np.array(img)/255 

    # Normalize each color channel
    mean = [0.485, 0.456, 0.406]
    std = [0.229, 0.224, 0.225]
    numpy_img = (numpy_img-mean)/std
        
    # Set the color to the first channel
    numpy_img = numpy_img.transpose(2, 0, 1)
    
    return numpy_img

# %% [markdown]
# To check your work, the function below converts a PyTorch tensor and displays it in the notebook. If your `process_image` function works, running the output through this function should return the original image (except for the cropped out portions).

# %%
def imshow(image, ax=None, title=None):
    #img for tensor
    if ax is None:
        fig, ax = plt.subplots()
    
    # PyTorch tensors assume the color channel is the first dimension
    # but matplotlib assumes is the third dimension
    image = image.transpose((1, 2, 0))   
    # Undo preprocessing
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    image = std * image + mean
    
    # Image needs to be clipped between 0 and 1 or it looks like noise when displayed
    image = np.clip(image, 0, 1)
    
    ax.imshow(image)
    
    return ax

imshow(process_image("flowers/test/9/image_06413.jpg"))
imshow(process_image("flowers/test/37/image_03734.jpg"))
imshow(process_image("flowers/test/10/image_07090.jpg"));

# %% [markdown]
# ## Class Prediction
#
# Once you can get images in the correct format, it's time to write a function for making predictions with your model. A common practice is to predict the top 5 or so (usually called top-$K$) most probable classes. You'll want to calculate the class probabilities then find the $K$ largest values.
#
# To get the top $K$ largest values in a tensor use [`x.topk(k)`](http://pytorch.org/docs/master/torch.html#torch.topk). This method returns both the highest `k` probabilities and the indices of those probabilities corresponding to the classes. You need to convert from these indices to the actual class labels using `class_to_idx` which hopefully you added to the model or from an `ImageFolder` you used to load the data ([see here](#Save-the-checkpoint)). Make sure to invert the dictionary so you get a mapping from index to class as well.
#
# Again, this method should take a path to an image and a model checkpoint, then return the probabilities and classes.
#
# ```python
# probs, classes = predict(image_path, model)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```

# %%
def predict(image_path, model, top_k=5):
    ''' Predict the class (or classes) of an image using a trained deep learning model.
    
    image_path: string. Path to image, directly to image and not to folder.
    model: pytorch neural network.
    top_k: integer. The top K classes to be calculated
    
    returns top_probabilities(k), top_labels
    '''
    
    # No need for GPU on this part (just causes problems)
    model.to("cpu")
    
    # Set model to evaluate
    model.eval();

    # Convert image from numpy to torch
    torch_image = torch.from_numpy(np.expand_dims(process_image(image_path), 
                                                  axis=0)).type(torch.FloatTensor).to("cpu")

    # Find probabilities (results) by passing through the function (note the log softmax means that its on a log scale)
    log_probs = model.forward(torch_image)

    # Convert to linear scale
    linear_probs = torch.exp(log_probs)

    # Find the top 5 results
    top_probs, top_labels = linear_probs.topk(top_k)
    
    # Detatch all of the details
    top_probs = np.array(top_probs.detach())[0] # This is not the correct way to do it but the correct way isnt working thanks to cpu/gpu issues so I don't care.
    top_labels = np.array(top_labels.detach())[0]
    
    # Convert to classes
    idx_to_class = {val: key for key, val in    
                                      model.class_to_idx.items()}
    top_labels = [idx_to_class[lab] for lab in top_labels]
    top_flowers = [cat_to_name[lab] for lab in top_labels]
    
    return top_probs, top_labels, top_flowers

# %% [markdown]
# ## Sanity Checking
#
# Now that you can use a trained model for predictions, check to make sure it makes sense. Even if the testing accuracy is high, it's always good to check that there aren't obvious bugs. Use `matplotlib` to plot the probabilities for the top 5 classes as a bar graph, along with the input image. It should look like this:
#
# <img src='assets/inference_example.png' width=300px>
#
# You can convert from the class integer encoding to actual flower names with the `cat_to_name.json` file (should have been loaded earlier in the notebook). To show a PyTorch tensor as an image, use the `imshow` function defined above.

# %%
# TODO: Display an image along with the top 5 classes
# Define image path
image_path = "flowers/test/37/image_03734.jpg"

# Set up plot
plt.figure(figsize = (6,10))
ax = plt.subplot(2,1,1)

# Set up title
flower_num = image_path.split('/')[2]
title_ = cat_to_name[flower_num]

# Plot flower
img = process_image(image_path)
imshow(img, ax, title = title_);

# Make prediction
probs, labs, flowers = predict(image_path, model) 

# Plot bar chart
plt.subplot(2,1,2)
sns.barplot(x=probs, y=flowers, color=sns.color_palette()[0]);
plt.show();

# %%
image_path = "flowers/test/9/image_06413.jpg"
plt.figure(figsize = (6,10))
ax = plt.subplot(2,1,1)
flower_num = image_path.split('/')[2]
title_ = cat_to_name[flower_num]
img = process_image(image_path)
imshow(img, ax, title = title_);
probs, labs, flowers = predict(image_path, model) 
plt.subplot(2,1,2)
sns.barplot(x=probs, y=flowers, color=sns.color_palette()[0]);
plt.show();

# %% [markdown]
# <font color='red'>**Reminder for Workspace users:** If your network becomes very large when saved as a checkpoint, there might be issues with saving backups in your workspace. You should reduce the size of your hidden layers and train again.
#
# We strongly encourage you to delete these large interim files and directories before navigating to another page or closing the browser tab.</font>

# %%
# TODO remove .pth files or move it to a temporary `~/opt` directory in this Workspace
